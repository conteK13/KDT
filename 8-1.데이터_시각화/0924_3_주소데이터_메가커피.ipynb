# %% [markdown]
# # 0) 필요한 모듈 설치

# %%
! pip3 install --upgrade pandas

# %%
! pip install geopy

# %% [markdown]
# # 1) 필요한 모듈 import

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rcParams, style
from matplotlib import font_manager, rc
import os

pd.set_option('mode.chained_assignment', None) # Warning 방지용

# %% [markdown]
# # 2) 데이터 load

# %%
# 메가커 현황 데이터 로드

data = pd.read_csv('Megacoffee_utf8.csv', index_col=0, encoding='utf8', engine='python')
# index_col=0 : index 열 설정
# header=0 : 열 이름(헤더) 설정

# 'python'의 의미: 기본 엔진인 'c' 대신에 'python' 엔진을 사용하겠다는 의미입니다.
# 'python' 엔진은 좀 더 유연하지만 속도가 느릴 수 있습니다.
# 일반적으로 데이터에 특수 문자가 포함되어 있거나 복잡한 형식을 가진 경우 'python' 엔진을 사용하는 것이 유리합니다.


data.head() #작업내용 확인용 출력
# Out:
#              지역                                                주소  \
# 매장명
# 동서울대점        경기                       경기 성남시 수정구 복정로 73 (복정동), 1층
# 동서울터미널점      서울                  서울 광진구 강변역로4길 10 (구의동, 강변역지너스타워)
# 북서울꿈의숲점      서울  서울 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트), 상가104동 107호
# 삼육서울병원점   서울특별시                        서울특별시 동대문구 망우로 78, 1층(휘경동)
# 서서울호수공원점     서울                            서울 양천구 남부순환로 432 (신월동)
#
#                   전화번호
# 매장명
# 동서울대점     031-722-0111
# 동서울터미널점    02-454-1003
# 북서울꿈의숲점    02-912-8982
# 삼육서울병원점   02-2213-2322
# 서서울호수공원점  02-2690-6011

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2922 entries, 동서울대점 to 협재해수욕장점
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      2922 non-null   object
#  1   주소      2922 non-null   object
#  2   전화번호    2922 non-null   object
# dtypes: object(3)
# memory usage: 91.3+ KB

# %%
# 현재 행정구역으로 업데이트(2024.09.24 기준)
# 세종특별자치시 에는 '군구'없이 '행정동'만 가지고 있습니다.
# '강원도'의 정식 명칭은 '강원특별자치도'입니다.
# '전라북도'의 정식 명칭은 '전북특별자치도'입니다.

# 행정구역 딕셔너리
Korea_district = {
    '서울특별시': ['종로구', '중구', '용산구', '성동구', '광진구', 
                  '동대문구', '중랑구', '성북구', '강북구', '도봉구', 
                  '노원구', '은평구', '서대문구', '마포구', '양천구', 
                  '강서구', '구로구', '금천구', '영등포구', '동작구', 
                  '관악구', '서초구', '강남구', '송파구', '강동구'],
    
    '부산광역시': ['중구', '서구', '동구', '영도구', '부산진구', 
                  '동래구', '남구', '북구', '해운대구', '사하구', 
                  '금정구', '강서구', '연제구', '수영구', '사상구', '기장군'],

    '대구광역시': ['중구', '동구', '서구', '남구', '북구', '수성구', '달서구', '달성군', '군위군'],

    '인천광역시': ['중구', '동구', '미추홀구', '연수구', '남동구', 
                  '부평구', '계양구', '서구', '강화군', '옹진군'],
    
    '광주광역시': ['동구', '서구', '남구', '북구', '광산구'],

    '대전광역시': ['동구', '중구', '서구', '유성구', '대덕구'],

    '울산광역시': ['중구', '남구', '동구', '북구', '울주군'],

    '세종특별자치시': ['세종시'],

    '경기도': ['수원시', '용인시', '고양시', '화성시', '성남시', 
              '부천시', '남양주시', '안산시', '평택시', '안양시', 
              '시흥시', '파주시', '김포시', '의정부시', '광주시',
              '하남시', '광명시', '군포시', '양주시', '오산시',
              '이천시', '안성시', '구리시', '의왕시', '포천시',
              '양평군', '여주시', '동두천시', '과천시',  '가평군', 
              '연천군'],

    '강원도': ['춘천시', '원주시', '강릉시', '동해시', '태백시', 
              '속초시', '삼척시', '홍천군', '횡성군', '영월군', 
              '평창군', '정선군', '철원군', '화천군', '양구군', 
              '인제군', '고성군', '양양군'],

    '충청북도': ['청주시', '충주시', '제천시', '보은군', '옥천군', 
               '영동군', '증평군', '진천군', '괴산군', '음성군', 
               '단양군'],

    '충청남도': ['천안시', '공주시', '보령시', '아산시', '서산시', 
               '논산시', '계룡시', '당진시', '금산군', '부여군', 
               '서천군', '청양군', '홍성군', '예산군', '태안군'],

    '전라북도': ['전주시', '군산시', '익산시', '정읍시', '남원시', 
               '김제시', '완주군', '진안군', '무주군', '장수군', 
               '임실군', '순창군', '고창군', '부안군'],

    '전라남도': ['목포시', '여수시', '순천시', '나주시', '광양시', 
               '담양군', '곡성군', '구례군', '고흥군', '보성군', 
               '화순군', '장흥군', '강진군', '해남군', '영암군', 
               '무안군', '함평군', '영광군', '장성군', '완도군', 
               '진도군', '신안군'],

    '경상북도': ['포항시', '경주시', '김천시', '안동시', '구미시', 
               '영주시', '영천시', '상주시', '문경시', '경산시', 
               '의성군', '청송군', '영양군', '영덕군', '청도군', 
               '고령군', '성주군', '칠곡군', '예천군', '봉화군', 
               '울진군', '울릉군'],

    '경상남도': ['창원시', '진주시', '통영시', '사천시', '김해시', 
               '밀양시', '거제시', '양산시', '의령군', '함안군', 
               '창녕군', '고성군', '남해군', '하동군', '산청군', 
               '함양군', '거창군', '합천군'],

    '제주특별자치도': ['제주시', '서귀포시']
}

# %% [markdown]
# # 3) 데이터 준비

# %% [markdown]
# ## 3-1) 주소를 시도/군구 로 나누기

# %%
## 주소에서 시도, 군구 정보 분리

addr = pd.DataFrame(data['주소'].apply(lambda v: v.split()[:2]).tolist(),
                    columns=('시도', '군구'))

addr.head()  #작업내용 확인용 출력
# Out:
#       시도    군구
# 0     경기   성남시
# 1     서울   광진구
# 2     서울   성북구
# 3  서울특별시  동대문구
# 4     서울   양천구

# %%
addr['시도'].unique()
# Out:
# array(['경기', '서울', '서울특별시', '충청남도', '경기도', '인천', '인천광역시', '강원', '강원특별자치도',
#        '강원도', '광주', '광주광역시', '대전', '대전광역시', '대구', '대구광역시', '경상북도',
#        '부산광역시', '부산', '울산광역시', '울산', '세종특별자치시', '경남', '경상남도', '경북',
#        '전라남도', '전남', '전라북도', '전북', '전북특별자치도', '충남', '충북', '충청북도',
#        '제주특별자치도'], dtype=object)

# %%
#korea_district의 key값으로 리스트를 만든다.
district_keys = list(Korea_district.keys())

# addr['시도'].unique()의 값을 sido에 대입한다.
# district_keys에 들어있지 않은 경우 sido 값을 not_matcing에 입력한다.
non_matching = [sido for sido in addr['시도'].unique() if sido not in district_keys]

print(non_matching)
# Out:
# ['경기', '서울', '인천', '강원', '강원특별자치도', '광주', '대전', '대구', '부산', '울산', '경남', '경북', '전남', '전북', '전북특별자치도', '충남', '충북']

# %%
## 표준 행정구역 이름으로 수정 :  경기 -> 경기도, 경남 -> 경상남도, ...
addr_aliases = {'경기':'경기도', '서울':'서울특별시', '인천':'인천광역시',
                '강원':'강원도', '강원특별자치도':'강원도', 
                '광주':'광주광역시', '대전':'대전광역시', '대구':'대구광역시', 
                '부산':'부산광역시', '울산':'울산광역시',
                '경남':'경상남도', '경북':'경상북도', '전남':'전라남도', '전북':'전라북도',
                '전북특별자치도':'전라북도', '충남':'충청남도', '충북':'충청북도'
                }

addr['시도']= addr['시도'].apply(lambda v: addr_aliases.get(v, v))

non_matching = [sido for sido in addr['시도'].unique() if sido not in district_keys]

print(non_matching)
# Out:
# []

# %%
addr['시도'].unique()

# %%
addr['군구'].unique()

# %%
# 딕셔너리의 value와 key를 반대로 매핑
district_mapping = {value: key for key, values in Korea_district.items() for value in values}
district_keys = list(Korea_district.keys())

non_matching2 = [sido2 for sido2 in addr['군구'].unique() if (sido2 not in district_mapping)]

print(non_matching2)

# %%
# non_matching_gungu에 해당하고 '시도'가 '세종특별자치시'인 모든 행 찾기
result = addr[(addr['군구'].isin(non_matching2)) & (addr['시도'] == '세종특별자치시')]

result

# %%
addr.loc[addr['군구'].isin(non_matching2) & (addr['시도'] == '세종특별자치시'), '군구'] = np.nan  # NaN으로 설정
# result.loc['군구'] = np.NaN
addr.iloc[2635:2656]

# %%
# 딕셔너리의 value와 key를 반대로 매핑
district_mapping = {value: key for key, values in Korea_district.items() for value in values}
district_keys = list(Korea_district.keys())

non_matching2 = [sido2 for sido2 in addr['군구'].unique() if (sido2 not in district_mapping)]

print(non_matching2)

# %% [markdown]
# ## 3-2 위도 경도 구하기

# %%
data['주소2'] = data['주소'].apply(lambda x: x.split(',')[0])
data.head()
data['주소3'] = data['주소'].apply(lambda x: x.split('(')[0])
data.head()
# Out:
#              지역                                                주소  \
# 매장명
# 동서울대점        경기                       경기 성남시 수정구 복정로 73 (복정동), 1층
# 동서울터미널점      서울                  서울 광진구 강변역로4길 10 (구의동, 강변역지너스타워)
# 북서울꿈의숲점      서울  서울 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트), 상가104동 107호
# 삼육서울병원점   서울특별시                        서울특별시 동대문구 망우로 78, 1층(휘경동)
# 서서울호수공원점     서울                            서울 양천구 남부순환로 432 (신월동)
#
#                   전화번호                      주소2                    주소3
# 매장명
# 동서울대점     031-722-0111  경기 성남시 수정구 복정로 73 (복정동)     경기 성남시 수정구 복정로 73
# 동서울터미널점    02-454-1003    서울 광진구 강변역로4길 10 (구의동      서울 광진구 강변역로4길 10
# 북서울꿈의숲점    02-912-8982     서울 성북구 돌곶이로 220 (장위동       서울 성북구 돌곶이로 220
# 삼육서울병원점   02-2213-2322        서울특별시 동대문구 망우로 78  서울특별시 동대문구 망우로 78, 1층
# 서서울호수공원점  02-2690-6011   서울 양천구 남부순환로 432 (신월동)      서울 양천구 남부순환로 432

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time

# Nominatim 초기화
geolocator = Nominatim(user_agent="myGeocoder")

data_part = data.iloc[:50]

# 위경도를 얻기 위한 함수 정의
def get_lat_long(address):
    try:
        location = geolocator.geocode(address)
        if location:
            print(location.latitude, location.longitude)
            return location.latitude, location.longitude
        else:
            return None, None  # 주소가 유효하지 않을 경우
    except GeocoderTimedOut:
        time.sleep(1)
        return get_lat_long(address)  # 타임아웃 발생 시 재귀 호출

# '위도'와 '경도' 열 추가
data_part['위도'], data_part['경도'] = zip(*data_part['주소2'].apply(get_lat_long))

# 결과 출력
data_part.head()
# Out:
# 37.619671 127.0461571
# 37.5897081 127.0620209
# 37.5291614 126.8326238
# 37.5448427 126.9515367
# 37.4882373 127.0120067
# 37.5152469 127.1040621
# 37.4826746 126.9530317
# 37.4824722 126.9412128
# 37.45811495 126.95216069831967
# 37.554538 126.9636814
# 37.5819304 126.9239316
# 37.6017392 126.954885
# 37.5522844 126.9087685
# 37.5538464 127.0437701
# 37.58396795 127.05363002560506
# 37.567572299999995 126.97986005893793
# 37.6240955 127.08963750593591
# 37.5396211 126.9733282
# 37.5551129 126.9657954
# 37.6397628 126.9169905
# 37.5297106 127.1149633
# 37.556834249999994 126.83738998476841
# 36.9119039 127.1394544
# 37.6492703 127.0138004
# 37.5658833 126.9859321
# 37.5193784 126.9314564
# 37.5693472 126.9686176
# 37.4964556 127.11348224039948
# 37.4956352 127.1187337
# 37.49632 127.1316
# 37.5244909 127.0235968
# 37.4783003 126.8825117
# 37.4771329 126.8849089
# 37.477854 126.880425
# 37.4802575 126.8789252
# 37.477854 126.880425
#              지역                                                주소  \
# 매장명
# 동서울대점        경기                       경기 성남시 수정구 복정로 73 (복정동), 1층
# 동서울터미널점      서울                  서울 광진구 강변역로4길 10 (구의동, 강변역지너스타워)
# 북서울꿈의숲점      서울  서울 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트), 상가104동 107호
# 삼육서울병원점   서울특별시                        서울특별시 동대문구 망우로 78, 1층(휘경동)
# 서서울호수공원점     서울                            서울 양천구 남부순환로 432 (신월동)
#
#                   전화번호                      주소2         위도          경도
# 매장명
# 동서울대점     031-722-0111  경기 성남시 수정구 복정로 73 (복정동)        NaN         NaN
# 동서울터미널점    02-454-1003    서울 광진구 강변역로4길 10 (구의동        NaN         NaN
# 북서울꿈의숲점    02-912-8982     서울 성북구 돌곶이로 220 (장위동  37.619671  127.046157
# 삼육서울병원점   02-2213-2322        서울특별시 동대문구 망우로 78  37.589708  127.062021
# 서서울호수공원점  02-2690-6011   서울 양천구 남부순환로 432 (신월동)  37.529161  126.832624

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time

# Nominatim 초기화
geolocator = Nominatim(user_agent="myGeocoder")

data_part = data.iloc[:50]

# 위경도를 얻기 위한 함수 정의
def get_lat_long(address):
    try:
        location = geolocator.geocode(address)
        if location:
            print(location.latitude, location.longitude)
            return location.latitude, location.longitude
        else:
            return None, None  # 주소가 유효하지 않을 경우
    except GeocoderTimedOut:
        time.sleep(1)
        return get_lat_long(address)  # 타임아웃 발생 시 재귀 호출

# '위도'와 '경도' 열 추가
data_part['위도'], data_part['경도'] = zip(*data_part['주소3'].apply(get_lat_long))

# 결과 출력
data_part.head()
# Out:
# 37.5354326 127.0935432
# 37.6157379 127.0500699
# 37.5195455 126.8384331
# 37.6255545 126.918725
# 37.5448427 126.9515367
# 37.4882373 127.0120067
# 37.52641 127.1181368
# 37.4824722 126.9412128
# 37.45811495 126.95216069831967
# 37.5571314 126.9686222
# 37.5819304 126.9239316
# 37.6008507 126.9567729
# 37.5522844 126.9087685
# 37.5839449 127.0535993
# 37.5068934 126.8787724
# 37.650058 127.0260842
# 37.6240485 127.0895786
# 37.5557831 126.9677701
# 37.6437578 127.0302076
# 37.6397628 126.9169905
# 37.4868596 126.9477174
# 37.6759999 127.0873997
# 37.5960022 127.08320423677911
# 37.3722272 126.7271386
# 37.4853076 126.91645
# 37.5358019 126.8981214
# 37.5656885 126.98724979962262
# 37.5193784 126.9314564
# 37.5693472 126.9686176
# 37.5192331 127.0230573
# 37.48195 126.88525
# 37.4802575 126.8789252
# 37.4802575 126.8789252
#              지역                                                주소  \
# 매장명
# 동서울대점        경기                       경기 성남시 수정구 복정로 73 (복정동), 1층
# 동서울터미널점      서울                  서울 광진구 강변역로4길 10 (구의동, 강변역지너스타워)
# 북서울꿈의숲점      서울  서울 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트), 상가104동 107호
# 삼육서울병원점   서울특별시                        서울특별시 동대문구 망우로 78, 1층(휘경동)
# 서서울호수공원점     서울                            서울 양천구 남부순환로 432 (신월동)
#
#                   전화번호                      주소2                    주소3  \
# 매장명
# 동서울대점     031-722-0111  경기 성남시 수정구 복정로 73 (복정동)     경기 성남시 수정구 복정로 73
# 동서울터미널점    02-454-1003    서울 광진구 강변역로4길 10 (구의동      서울 광진구 강변역로4길 10
# 북서울꿈의숲점    02-912-8982     서울 성북구 돌곶이로 220 (장위동       서울 성북구 돌곶이로 220
# 삼육서울병원점   02-2213-2322        서울특별시 동대문구 망우로 78  서울특별시 동대문구 망우로 78, 1층
# 서서울호수공원점  02-2690-6011   서울 양천구 남부순환로 432 (신월동)      서울 양천구 남부순환로 432
#
#                  위도          경도
# 매장명
# 동서울대점           NaN         NaN
# 동서울터미널점   37.535433  127.093543
# 북서울꿈의숲점   37.615738  127.050070
# 삼육서울병원점         NaN         NaN
# 서서울호수공원점  37.519545  126.838433

# %%
data_part.head(50)
# Out:
#                지역                                                 주소  \
# 매장명
# 동서울대점          경기                        경기 성남시 수정구 복정로 73 (복정동), 1층
# 동서울터미널점        서울                   서울 광진구 강변역로4길 10 (구의동, 강변역지너스타워)
# 북서울꿈의숲점        서울   서울 성북구 돌곶이로 220 (장위동, 꿈의숲코오롱하늘채아파트), 상가104동 107호
# 삼육서울병원점     서울특별시                         서울특별시 동대문구 망우로 78, 1층(휘경동)
# 서서울호수공원점       서울                             서울 양천구 남부순환로 432 (신월동)
# 서울갈현초점         서울                           서울 은평구 갈현로 260 (갈현동), 1층
# 서울공덕초교점     서울특별시                        서울특별시 마포구 만리재옛길 6, 1층(신공덕동)
# 서울교대사거리점       서울                         서울 서초구 서초중앙로 72 (서초동, 영빌딩)
# 서울교통회관점        서울             서울 송파구 올림픽로 319 (신천동, 사단법인 서울특별시 교통회관)
# 서울대입구역점     서울특별시        서울특별시 관악구 관악로 195, 제1층 제115호(봉천동 , 관악위버폴리스)
# 서울대입구점      서울특별시               서울특별시 관악구 남부순환로 1861 , (봉천동, 덕수빌딩)1층
# 서울대잔디광장점       서울        서울 관악구 관악로 1 (신림동, 서울대학교), 관악60-1동 잔디광장 B1F
# 서울만리점          서울           서울 중구 만리재로 175 (만리동2가), 1층 (서울역 센트럴자이상가)
# 서울명지초점         서울                              서울 서대문구 가좌로 102 (홍은동)
# 서울상명대점         서울                              서울 종로구 홍지문2길 11 (홍지동)
# 서울성산초점         서울                      서울 마포구 월드컵로 37 (합정동, 합정동웰빙센터)
# 서울숲역점       서울특별시                    서울특별시 성동구 왕십리로 94-1, 1층 (성수동1가)
# 서울시립대점      서울특별시                      서울특별시 동대문구 전농로 222 , 1층 (전농동)
# 서울시청점       서울특별시                         서울특별시 중구 다동길 34, 1 ,2호(다동)
# 서울신미림초점        서울                               서울 구로구 신도림로 7 (신도림동)
# 서울쌍문초점         서울                             서울 도봉구 노해로41길 32 (쌍문동)
# 서울여대점          서울          서울 노원구 화랑로51길 20 (공릉동, 공릉동 진성빌딩), 1층 103호
# 서울역점        서울특별시                        서울특별시 용산구 한강대로 403, 1층(동자동)
# 서울역한라비발디점      서울                서울 중구 만리재로 177 (만리동2가, 서울역한라비발디센트럴)
# 서울우이교사거리점      서울                              서울 도봉구 우이천로 284 (쌍문동)
# 서울은빛초점      서울특별시                서울특별시 은평구 진관3로 67 , (진관동, 은평뉴타운구파발)
# 서울은천초점         서울                         서울 관악구 은천로 84 (봉천동, 라이프빌딩)
# 서울중계초점         서울                               서울 노원구 덕릉로 663 (중계동)
# 서울중랑우체국점       서울                         서울 중랑구 망우로 275 (상봉동, 로젠하임)
# 서울풍납점       서울특별시                 서울특별시 송파구 토성로 59 , 1층 (풍납동 , 선일빌딩)
# 시흥서울대학로점       경기                     경기 시흥시 서울대학로 77 (배곧동, 골드테크노밸리)
# 안산서울예대점        경기                  경기 안산시 단원구 예술대학로 155 (고잔동), 1층 일부
# 이대서울병원점     서울특별시                      서울특별시 강서구 강서로 349 , 1층 (내발산동)
# 천안남서울대점      충청남도                     충청남도 천안시 서북구 성환읍 성진로 80-6 , 1층
# 난곡신사시장점        서울                               서울 관악구 조원로 136 (신림동)
# 선유도역점          서울                      서울 영등포구 양평로 127 (양평동5가, 성산빌딩)
# 419사거리점     서울특별시                        서울특별시 강북구 삼양로 510, 1층 (수유동)
# IBK파이낸스점       서울                    서울 중구 을지로 82 (을지로2가, IBK파이낸스타워)
# KBS별관점         서울                     서울 영등포구 여의대방로 383 (여의도동, 경도빌딩)
# LG광화문빌딩점       서울                    서울 종로구 새문안로 58 (신문로2가, LG광화문빌딩)
# 가락몰점        서울특별시  서울특별시 송파구 양재대로 932, 업무동 1층 로비(가락동 , 가락동 농수산물도매시장)
# 가락시장역점      서울특별시                서울특별시 송파구 중대로9길 21 , 1층 (가락동, 센터빌딩)
# 가락중앙점       서울특별시                        서울특별시 송파구 동남로 209, 1층 (가락동)
# 가로수길점          서울                               서울 강남구 가로수길 19 (신사동)
# 가산skv1센터점   서울특별시   서울특별시 금천구 가산디지털1로 171, 117호(가산동 ,가산 에스케이 브에원 센터)
# 가산그레이트밸리점      서울                   서울 금천구 디지털로9길 32 (가산동, 갑을그레이트밸리)
# 가산리더스타워점    서울특별시      서울특별시 금천구 벚꽃로 286, 지하 1층 B103호(가산동 , 삼성리더스타워)
# 가산어반워크점        서울                 서울 금천구 가산디지털2로 135 (가산동, 가산 어반워크I)
# 가산에이스K1타워점  서울특별시                     서울특별시 금천구 가산디지털2로 166, 1층(가산동)
# 가산한라원앤원점       서울                  서울 금천구 가산디지털2로 101 (가산동), 1층 111호
#
#                      전화번호                         주소2  \
# 매장명
# 동서울대점        031-722-0111     경기 성남시 수정구 복정로 73 (복정동)
# 동서울터미널점       02-454-1003       서울 광진구 강변역로4길 10 (구의동
# 북서울꿈의숲점       02-912-8982        서울 성북구 돌곶이로 220 (장위동
# 삼육서울병원점      02-2213-2322           서울특별시 동대문구 망우로 78
# 서서울호수공원점     02-2690-6011      서울 양천구 남부순환로 432 (신월동)
# 서울갈현초점        02-353-3321        서울 은평구 갈현로 260 (갈현동)
# 서울공덕초교점       02-712-5541           서울특별시 마포구 만리재옛길 6
# 서울교대사거리점      02-588-7080        서울 서초구 서초중앙로 72 (서초동
# 서울교통회관점       02-418-1002        서울 송파구 올림픽로 319 (신천동
# 서울대입구역점       02-871-9001           서울특별시 관악구 관악로 195
# 서울대입구점        02-878-4825       서울특별시 관악구 남부순환로 1861
# 서울대잔디광장점      02-877-0656           서울 관악구 관악로 1 (신림동
# 서울만리점        02-3147-2444      서울 중구 만리재로 175 (만리동2가)
# 서울명지초점        02-305-5557       서울 서대문구 가좌로 102 (홍은동)
# 서울상명대점        02-395-1322       서울 종로구 홍지문2길 11 (홍지동)
# 서울성산초점        02-325-3353         서울 마포구 월드컵로 37 (합정동
# 서울숲역점         02-468-2588         서울특별시 성동구 왕십리로 94-1
# 서울시립대점       02-3390-9880         서울특별시 동대문구 전농로 222
# 서울시청점        02-3789-0656             서울특별시 중구 다동길 34
# 서울신미림초점      02-2675-1110        서울 구로구 신도림로 7 (신도림동)
# 서울쌍문초점        02-900-6555      서울 도봉구 노해로41길 32 (쌍문동)
# 서울여대점         02-975-1009       서울 노원구 화랑로51길 20 (공릉동
# 서울역점          02-711-0543          서울특별시 용산구 한강대로 403
# 서울역한라비발디점     02-313-5493       서울 중구 만리재로 177 (만리동2가
# 서울우이교사거리점     02-991-1005       서울 도봉구 우이천로 284 (쌍문동)
# 서울은빛초점        02-356-8446          서울특별시 은평구 진관3로 67
# 서울은천초점        02-883-0603          서울 관악구 은천로 84 (봉천동
# 서울중계초점        02-933-1003        서울 노원구 덕릉로 663 (중계동)
# 서울중랑우체국점      02-433-1116         서울 중랑구 망우로 275 (상봉동
# 서울풍납점         02-429-3210           서울특별시 송파구 토성로 59
# 시흥서울대학로점    031-8040-7450        경기 시흥시 서울대학로 77 (배곧동
# 안산서울예대점      031-414-6646  경기 안산시 단원구 예술대학로 155 (고잔동)
# 이대서울병원점      02-6407-1711          서울특별시 강서구 강서로 349
# 천안남서울대점      041-588-3800  충청남도 천안시 서북구 성환읍 성진로 80-6
# 난곡신사시장점       02-838-8111        서울 관악구 조원로 136 (신림동)
# 선유도역점        02-2677-0523      서울 영등포구 양평로 127 (양평동5가
# 419사거리점       02-900-1288           서울특별시 강북구 삼양로 510
# IBK파이낸스점      02-755-1007         서울 중구 을지로 82 (을지로2가
# KBS별관점        02-780-1014     서울 영등포구 여의대방로 383 (여의도동
# LG광화문빌딩점      02-720-2018       서울 종로구 새문안로 58 (신문로2가
# 가락몰점        070-4924-0520          서울특별시 송파구 양재대로 932
# 가락시장역점       02-6486-0077         서울특별시 송파구 중대로9길 21
# 가락중앙점         02-406-6782           서울특별시 송파구 동남로 209
# 가로수길점         02-540-1041        서울 강남구 가로수길 19 (신사동)
# 가산skv1센터점    02-6244-8028       서울특별시 금천구 가산디지털1로 171
# 가산그레이트밸리점     02-855-6801       서울 금천구 디지털로9길 32 (가산동
# 가산리더스타워점      02-855-9555           서울특별시 금천구 벚꽃로 286
# 가산어반워크점      02-6177-7575     서울 금천구 가산디지털2로 135 (가산동
# 가산에이스K1타워점   02-6464-1877       서울특별시 금천구 가산디지털2로 166
# 가산한라원앤원점     02-2101-2090    서울 금천구 가산디지털2로 101 (가산동)
#
#                                        주소3         위도          경도
# 매장명
# 동서울대점                   경기 성남시 수정구 복정로 73         NaN         NaN
# 동서울터미널점                  서울 광진구 강변역로4길 10   37.535433  127.093543
# 북서울꿈의숲점                   서울 성북구 돌곶이로 220   37.615738  127.050070
# 삼육서울병원점              서울특별시 동대문구 망우로 78, 1층        NaN         NaN
# 서서울호수공원점                 서울 양천구 남부순환로 432   37.519545  126.838433
# 서울갈현초점                     서울 은평구 갈현로 260   37.625554  126.918725
# 서울공덕초교점              서울특별시 마포구 만리재옛길 6, 1층  37.544843  126.951537
# 서울교대사거리점                  서울 서초구 서초중앙로 72   37.488237  127.012007
# 서울교통회관점                   서울 송파구 올림픽로 319   37.526410  127.118137
# 서울대입구역점       서울특별시 관악구 관악로 195, 제1층 제115호        NaN         NaN
# 서울대입구점             서울특별시 관악구 남부순환로 1861 ,   37.482472  126.941213
# 서울대잔디광장점                     서울 관악구 관악로 1   37.458115  126.952161
# 서울만리점                      서울 중구 만리재로 175   37.557131  126.968622
# 서울명지초점                    서울 서대문구 가좌로 102   37.581930  126.923932
# 서울상명대점                    서울 종로구 홍지문2길 11   37.600851  126.956773
# 서울성산초점                     서울 마포구 월드컵로 37   37.552284  126.908768
# 서울숲역점             서울특별시 성동구 왕십리로 94-1, 1층         NaN         NaN
# 서울시립대점            서울특별시 동대문구 전농로 222 , 1층   37.583945  127.053599
# 서울시청점               서울특별시 중구 다동길 34, 1 ,2호        NaN         NaN
# 서울신미림초점                     서울 구로구 신도림로 7   37.506893  126.878772
# 서울쌍문초점                   서울 도봉구 노해로41길 32   37.650058  127.026084
# 서울여대점                    서울 노원구 화랑로51길 20   37.624049  127.089579
# 서울역점                서울특별시 용산구 한강대로 403, 1층        NaN         NaN
# 서울역한라비발디점                  서울 중구 만리재로 177   37.555783  126.967770
# 서울우이교사거리점                 서울 도봉구 우이천로 284   37.643758  127.030208
# 서울은빛초점                서울특별시 은평구 진관3로 67 ,   37.639763  126.916990
# 서울은천초점                      서울 관악구 은천로 84   37.486860  126.947717
# 서울중계초점                     서울 노원구 덕릉로 663   37.676000  127.087400
# 서울중랑우체국점                   서울 중랑구 망우로 275   37.596002  127.083204
# 서울풍납점               서울특별시 송파구 토성로 59 , 1층         NaN         NaN
# 시흥서울대학로점                  경기 시흥시 서울대학로 77   37.372227  126.727139
# 안산서울예대점              경기 안산시 단원구 예술대학로 155         NaN         NaN
# 이대서울병원점            서울특별시 강서구 강서로 349 , 1층         NaN         NaN
# 천안남서울대점     충청남도 천안시 서북구 성환읍 성진로 80-6 , 1층        NaN         NaN
# 난곡신사시장점                    서울 관악구 조원로 136   37.485308  126.916450
# 선유도역점                     서울 영등포구 양평로 127   37.535802  126.898121
# 419사거리점             서울특별시 강북구 삼양로 510, 1층         NaN         NaN
# IBK파이낸스점                     서울 중구 을지로 82   37.565689  126.987250
# KBS별관점                  서울 영등포구 여의대방로 383   37.519378  126.931456
# LG광화문빌딩점                   서울 종로구 새문안로 58   37.569347  126.968618
# 가락몰점         서울특별시 송파구 양재대로 932, 업무동 1층 로비        NaN         NaN
# 가락시장역점            서울특별시 송파구 중대로9길 21 , 1층         NaN         NaN
# 가락중앙점               서울특별시 송파구 동남로 209, 1층         NaN         NaN
# 가로수길점                      서울 강남구 가로수길 19   37.519233  127.023057
# 가산skv1센터점      서울특별시 금천구 가산디지털1로 171, 117호        NaN         NaN
# 가산그레이트밸리점                서울 금천구 디지털로9길 32   37.481950  126.885250
# 가산리더스타워점    서울특별시 금천구 벚꽃로 286, 지하 1층 B103호        NaN         NaN
# 가산어반워크점                서울 금천구 가산디지털2로 135   37.480258  126.878925
# 가산에이스K1타워점       서울특별시 금천구 가산디지털2로 166, 1층        NaN         NaN
# 가산한라원앤원점               서울 금천구 가산디지털2로 101   37.480258  126.878925

# %%
import pandas as pd
import folium


# 기본 맵 생성: 서울 시청 근처의 위도와 경도로 초기화
map_CB = folium.Map(location=[37.560284, 126.975334], zoom_start=15)

# 데이터프레임의 각 행을 순회
for i, store in data_part.iterrows():
    # 위도와 경도가 NaN이 아닌 경우에만 마커 추가
    if pd.notnull(store['위도']) and pd.notnull(store['경도']):
        folium.Marker(
            location=[store['위도'], store['경도']],  # 마커 위치 설정
            popup=i,  # 인덱스를 매장명으로 사용 (매장명이 인덱스에 있음)
            icon=folium.Icon(color='red', icon='star')  # 마커 아이콘 설정
        ).add_to(map_CB)  # 맵에 마커 추가

# 생성된 맵을 HTML 파일로 저장
map_CB.save('map_Mega.html')

# %%
import webbrowser
webbrowser.open('C:/Users/user/0Data/0924_/map_Mega.html')

# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
# \대신 / 사용
