# %% [markdown]
# # 텍스트 빈도 분석 -4 네이버 리뷰

# %% [markdown]
# ## 0)필요한 모듈 설치

# %%
# !pip install wordcloud

# %%
# !pip install xlrd

# %%
# !pip install konlpy

# %%
import nltk
nltk.download()

# %% [markdown]
# ## 1) 필요한 모듈 import

# %%
# import json
import re
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import STOPWORDS, WordCloud

import pandas as pd
# import glob
# from functools import reduce
# from nltk.tokenize import word_tokenize
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## 2) 데이터 load

# %%
import urllib.request

#네이버 쇼핑 리뷰 데이터
urllib.request.urlretrieve("https://raw.githubusercontent.com/bab2min/corpus/master/sentiment/naver_shopping.txt", filename="ratings_total.txt")

total_data = pd.read_table('ratings_total.txt', names=['ratings', 'reviews'])
total_data
# Out:
#         ratings                                            reviews
# 0             5                                            배공빠르고 굿
# 1             2                      택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고
# 2             5  아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다. 바느질이 조금 ...
# 3             2  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다. 전...
# 4             5                  민트색상 예뻐요. 옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ
# ...         ...                                                ...
# 199995        2                                    장마라그런가!!! 달지않아요
# 199996        5  다이슨 케이스 구매했어요 다이슨 슈퍼소닉 드라이기 케이스 구매했어요가격 괜찮고 배송...
# 199997        5                    로드샾에서 사는것보다 세배 저렴하네요 ㅜㅜ 자주이용할께요
# 199998        5                                      넘이쁘고 쎄련되보이네요~
# 199999        5   아직 사용해보지도않았고 다른 제품을 써본적이없어서 잘 모르겠지만 ㅎㅎ 배송은 빨랐습니다
#
# [200000 rows x 2 columns]

# %% [markdown]
# ## 3) 데이터 전처리

# %%
# 데이터가 너무 많아서 처리가 힘드므로, 1만 개의 리뷰만 가져옴
reviews = ''
for item in total_data['reviews'].iloc[0:10001]:
    reviews += re.sub(r'[^\w]', ' ', item) + ' '
reviews
# Out:
# '배공빠르고 굿 택배가 엉망이네용 저희집 밑에층에 말도없이 놔두고가고 아주좋아요 바지 정말 좋아서2개 더 구매했어요 이가격에 대박입니다  바느질이 조금 엉성하긴 하지만 편하고 가성비 최고예요  선물용으로 빨리 받아서 전달했어야 하는 상품이었는데 머그컵만 와서 당황했습니다  전화했더니 바로주신다했지만 배송도 누락되어있었네요   확인안하고 바로 선물했으면 큰일날뻔했네요  이렇게 배송이 오래걸렸으면 사는거 다시 생각했을거같아요 아쉽네요   민트색상 예뻐요  옆 손잡이는 거는 용도로도 사용되네요 ㅎㅎ 비추합니다 계란 뒤집을 때 완전 불편해요 ㅠㅠ 코팅도 묻어나고 보기엔 예쁘고 실용적으로 보였는데 생각보다 진짜 별로입니다  주문을 11월6에 시켰는데 11월16일에 배송이 왔네요 ㅎㅎㅎ 여기 회사측과는 전화도 안되고 아무런 연락을 받을수가 없으니 답답하신 분들은 다른곳에서 사시는거 추천드립니다 넉넉한 길이로 주문했는데도 안 맞네요 별로예요 보폴이 계속 때처럼 나오다가 지금은 안나네요  110인데 전문속옷브랜드 위생팬티105보다 작은듯해요  불편해요  밴딩부분이 다 신축성없는 일반실로 되어있어 빅사이즈임에도 빅사이즈같지않아요  입고벗을때 편하게 밴딩부분이 늘어나고 입었을때도 밴딩이 잡아주어야하는데 말이죠  사이즈도 딱이고 귀엽고 넘 좋아요 ㅎㅎ 베이지 색 구매했는데 약간 살색에 가까워요 화면빨인가봐요   노란컬러가 돋보여요   저렴한맛에 그냥 씁니다 별루 ㅏㅛㅇ치ㅗ티ㅓ치ㅗ탛캏타ㅗ티ㅗ티ㅗ티ㅛ티ㅛ티ㅗㅗㅗ치ㅕ치ㅕ쳐ㅣ처ㅣ치ㅓ처ㅣ펴ㅣ쳐ㅣ치ㅕㅐㅛㅌ쵸ㅔ려ㅔㅎ 촉감도 좋고 무게감이나 핏도 편합니다 불멍하기좋고 사이즈도 너무 좋아요 재구매 친구들이 좋은 향 난다고 해요 실내에서 신는건지 몰랐어요 재구매 다 좋은데 하나가 이상하네요 가게를 운영하는 사장님께서 대신 구매 해달라고 하셔서 구매하게되었는데 가게에 달아놓으니까 이쁘네요 가성비 괜찮습니다 바퀴가 고정된다면 별다섯개짜린데    화장이 깨끗하게 지워지지않아요 거품이생기고 오랫동안 문질러서 씻어내야하지만 세정력이 별로인듯해요 남자 애들 인데 너무 좋아요 유해성분없어 초등들도 바르기좋아요 채집통이 결착이 안됩니다  채집통이 결착이 안되서 커터칼로 결착 부분과 모서리 부분을 깍아 냈더니 겨우 결착이 됩니다 해당 부분은 제품 불량 이슈 같구요 보내시기 전에 최소한의 테스트는 하고 보내주세요  재구매 늘 사는 흙이에요 팽이들이 젤 좋아해요 빠른배송 감사합니다 처음 쓸때만 좋고 쓰다보니 의자뺄때 소리 계속 나요 그래서 붙이는부직포 덧붙였는데 여전히 끌리네요 비추에요 테니스공으로 살껄 이쁜거 산다고 이거 사서 후회되요 배송기사나  판매하는 회사나 불친절하고 불쾌합니다  서비스면에선 최악이네요 제품은 그럭저럭 쓸만합니다  싼게 비지떡 마인드부터 갖추고 장사하시길바랍니다  이익에 눈 저렴해서 구매 했지만 바지 완성도 떨어짐      사용이 불편하고 잘빠지네요ㅜ 양은 많은데 맛은 없었습니다 설치할때 전압이 넘 높아 퓨즈 나갔어여 첨에받았을땐 너무튼튼하구 칸막이도있구 넘맘에들었는데요    지금도맘에는들어요  근데    먼지가 먼지가 세상먼지다묻어요ㅠㅠ흑흑ㅠ 집에가만히 뒀는데도 먼지가다묻어있어요ㅠ 한번들고 그냥 모셔두었어요ㅜㅜ 까만색은 넘나비추입니다ㅠ 아이보리로살껄   ㅠ 휴대폰 각이 잘 안나옴 노트9 사용 얇은 케이스 꺼도 잘 빠지지가 않네요 진짜 불편한건 각도가 조절이 너무 조금 된다는 점 입니다     너무 생각보다 고급스럽 가볍고 좋아요  옵션에 파우치도 있었으면 얼마나 좋았을까 아쉽네요  따로 구매 했어요  잘 사용할께요  총 4개 샀는데 사용하기 전에 부드러운 물티슈로 닦았는데 프린트가 번졌네요 교환하기가 귀찮아서 그냥 쓰지만 아쉽네요 모기가 않들어가요ᆢ 선물준사람도 받은사람도 모두 만족했어요   예쁘고 심플해서 샀는데  재질이 깔끄러워요  살에 자국 다 베이고ㅠㅠ    폭망이에요  재대로 확인안한 제 잘못이죠    참고로 싱글세트 2  퀸세트 1 샀습니다  고정이 잘되기는 하는데 많이 쓰면 떡진것 처럼 보일까봐 걱정되서 많이 못쓰겠어요 맛있어서 주문합니다  카페갈 필요없음 진짜 너무하시네요 배송이늦는건 엄절수없다하고 참앗지만 밑에 서랍이 금방 안되서 AS되냐고 물어봣는데 전화도 안받고 10시에 톡을보냇는데 오후6시에 답해서 뭐하나물어보려고하니 상담시간이아니라고 뜨네요 빨리as좀 해주세요 안되면 안된다고 답장부탁드립니다 좋아요 색도 좋고 포근한 이불 네이비 색상이 조금 진한듯 하지만 굿 역시 기다린 보람이 있는 제품이군요   퀄리티 가 좀떨어지고 손이따로노는것 같아요 약간 삐뚤게 설치되네요   반품 귀찮아서 그냥 씁니다  피부 트러블 더 많이 올라와서 몸에 사용했는데 몸에도 뾰루지나네요ㅜ 겁나 아픈데 익숙해지면 된다길래 몇일 했더니 발에 멍들고 고통이 너무 심하고 컨디션이 더 안좋아져서 결국 패기처분 했네요  사람마다 다르니 사기전에 신중히 결정하세요  참고로 전 평발아닙니다  아직 이유식 초기라 사용하지않았지만 후기보고 믿고 구매했습니다  사이즈는 다양해서 너무 좋고요 실리콘재질이라 편하게 쓸거같아요 사이즈가 딱이에요   오자마자 쪄 먹엇는뎅 달디달아요 좀뻣뻣해서 애가 좋아하질않네요 생각보다 너무 작아서요 나중에 먼지먹는식물이나 넣어야겠어요 물건은 흠없습니다 세정력이 약해요  처음사용할 땐 세제찌꺼기가 없어서 좋다고 했는데 2 3 사용해보니 너무 안씻겨요  지멘스랑 안맞는건지     다시 쓰던 고체형으로 갈아탔습니다  흡착력이 너무 약해요  ㅠ 식판은 잘붙는데 이거는 애기가 자꾸 떼네요 재구매 짱구오빠네 소개로 이용했는데 저번엔 괜찮은거 같아서 또 샀는데 기름만 엄청 오고 질겨서 다 뱉었네요   좋은상품주시지 고객한명 잃으셨네요 ㅠ 이제 이용안하려고요 연휴때 시켯더니 연휴때 시켰더니 한달넘어서 왓네요 연락도 없고 택배회사도 연락없고 상품은 좋으나 너무 늦게와서 별로네요 저번에 쓰던게 망가져서 삿는데 역시 핸들돌릴때 편하네요 빠른 배송과 친절한 설명 빠른 배송 짱짱 오돌뼈 최고네요     안에 패드가 자꾸 빠져서 불편합니다 재구매 가게에서 사용중입니다  안주디피할때 이쁩니다  큰사이즈를 구매해서 언제 끝낼지는 모르겠지만 프린트도 선명하고 좋아요  너무예뻐요 포인트로딱이네요 보온 기능이 짱 최고입니다 강추 시간이 지나도 접착력이 그대로예요   괜찮네yo  지퍼 한번쓰고 고장남 최악 무게가 많이 나가요 연마제 닦느라 애먹었네요 신중하게 선택하세요  가격대비 너무 허접해요  쌓아놓으니 앞으로 기울고  내구성이 5점이기에 믿고 구입했는데 생각만큼 튼튼하지는 않네요 흰색이라 깔끔하고 아기쓰는건데 재질도 좋고 부드럽네요 항상 애용해서 ㅋㅋㅋ리뷰남기기도뭐하네요ㅋㅋ이것만 먹어요 배송도 빨라요 아주 편하진 않아요 밑위가 좀더길면 편할텐데 수딩젤만 바르면 오히려 더 건조해지는데 크림까지 발라주니 보습 잘 되고 좋아요 믿고쓰는 페넬로페   세자린쓰다가 새로 나온 제품이라서 구매했어요ㅎㅎ 세자린 마지막 팩쓰고 있는데  떨어지기 전에 도착했네요   실망이네요 마무리처리가 너무엉성합니다 한사이즈 크게 시켰는데 잘 맞아요ㅋㅋㅋ 재구매 3통짼대 아주좋네요 강추 5센치 토퍼 사용하는데 사이즈 잘 맞고 좋았아요  배송은 좀 늦게 왔네요    좋아요  몇번을써도괜찮은거같네요 재구매 환불건 처리해주세요  두께감도 적당하고 생각햇던것보다 더 괜찮아요  다음에도 갈색으로 사야겟어요  빠른 배송은 마음에 드는데 사진과 다른 증정품을 주셨네요  변경 되었으면 미리 고지해주셨으면 합니다  재구매 항상믿고구매하는곳이라   ㅋ 가격대비최고죵   싸비스두최공   바람이 나는지 잘 모르겠네요 크기도 생각보다 크고요 심이 있어 쪄서 갈아 먹었는데도 안갈린건 입안에서 걸리더라구요  선물로보냈는데 잘받았되요 필수입니다 꼭 같이 구매하세요 촉감 너무꺼끌하고 별로예요 시원한지도 잘모르겠고 반품귀찮아서 그냥씁니다 여유있게 보내주셨네요 잘쓸게요 가성비 최고 불도 밝고 이뻐요 여기상품좋다는지인추천에주문해봣는데 꾸준히써볼께요 재구매 회사에서 쓰는거라 자주 주문하고있어요  좀 빨리 떨어지는거 같긴한데   그냥 쓰고 있어요  배송은 빨라요 설치도 쉽고 화질도 좋고 넘 좋네요 아기목욕시키는데 잘쓰고 있긴한데 안전바는 잘안쓰게되네요 그리고 세면대에 설치한 시트는 밑에 고정다리가 좀  ...

# %%
# 품사 태깅
nlp = Okt()
reviews_N = nlp.nouns(reviews)
reviews_N
# Out:
# ['배공',
#  '굿',
#  '택배',
#  '엉망',
#  '용',
#  '집',
#  '밑',
#  '층',
#  '말',
#  '아주',
#  '바지',
#  '정말',
#  '개',
#  '더',
#  '구매',
#  '가격',
#  '대박',
#  '바느질',
#  '조금',
#  '가성',
#  '비',
#  '최고',
#  '선물',
#  '용',
#  '전달',
#  '상품',
#  '머그컵',
#  '당황',
#  '바로',
#  '배송',
#  '누락',
#  '확인',
#  '안',
#  '바로',
#  '선물',
#  '큰일',
#  '날',
#  '배송',
#  '다시',
#  '생각',
#  '민트',
#  '색상',
#  '옆',
#  '손잡이',
#  '거',
#  '용',
#  '도로',
#  '사용',
#  '계란',
#  '때',
#  '완전',
#  '코팅',
#  '보기',
#  '실용',
#  '생각',
#  '진짜',
#  '별로',
#  '주문',
#  '배송',
#  '여기',
#  '회사',
#  '전화',
#  '연락',
#  '분',
#  '곳',
#  '추천',
#  '길이',
#  '주문',
#  '안',
#  '별로',
#  '보폴',
#  '계속',
#  '때',
#  '지금',
#  '안나',
#  '전문',
#  '속옷',
#  '브랜드',
#  '위생',
#  '팬티',
#  '해',
#  '밴딩부분',
#  '신축',
#  '일반',
#  '실로',
#  '빅사',
#  '임',
#  '빅사',
#  '이즈',
#  '벗',
#  '때',
#  '밴딩부분',
#  '때',
#  '밴딩',
#  '말',
#  '사이즈',
#  '베이지',
#  '색',
#  '구매',
#  '약간',
#  '살색',
#  '화면',
#  '빨',
#  '컬러',
#  '맛',
#  '그냥',
#  '별루',
#  '치',
#  '티',
#  '치',
#  '탛캏타',
#  '티',
#  '티',
#  '티',
#  '티',
#  '티',
#  '치',
#  '치',
#  '처',
#  '치',
#  '처',
#  '치',
#  '려',
#  '촉감',
#  '무게',
#  '감',
#  '핏',
#  '불',
#  '사이즈',
#  '친구',
#  '향',
#  '해',
#  '실내',
#  '하나',
#  '가게',
#  '운영',
#  '사장',
#  '대신',
#  '구매',
#  '구매',
#  '가게',
#  '가성',
#  '비',
#  '바퀴',
#  '고정',
#  '개',
#  '린데',
#  '화장',
#  '거품',
#  '생기',
#  '정력',
#  '별로',
#  '듯해',
#  '남자',
#  '애',
#  '유해',
#  '성분',
#  '초등',
#  '채집',
#  '통',
#  '결착',
#  '채집',
#  '통',
#  '결착',
#  '커터칼',
#  '결착',
#  '부분',
#  '모서리',
#  '부분',
#  '깍',
#  '겨우',
#  '결착',
#  '해당',
#  '부분',
#  '제품',
#  '불량',
#  '이슈',
#  '전',
#  '최소한',
#  '테스트',
#  '늘',
#  '흙',
#  '팽이',
#  '젤',
#  '배송',
#  '처음',
#  '때',
#  '의자',
#  '때',
#  '소리',
#  '계속',
#  '부직포',
#  '테니스공',
#  '살껄',
#  '산다',
#  '거',
#  '사서',
#  '배송',
#  '기사',
#  '판매',
#  '회사',
#  '서비스',
#  '면',
#  '최악',
#  '요',
#  '제품',
#  '비지',
#  '떡',
#  '마인드',
#  '장사',
#  '이익',
#  '눈',
#  '구매',
#  '바지',
#  '완성',
#  '사용',
#  '양은',
#  '맛',
#  '설치',
#  '때',
#  '전압',
#  '퓨즈',
#  '땐',
#  '칸막이',
#  '맘',
#  '금도',
#  '맘',
#  '먼지',
#  '먼지',
#  '세상',
#  '먼지',
#  '집',
#  '먼지',
#  '한번',
#  '그냥',
#  '까만색',
#  '아이보리',
#  '살껄',
#  '휴대폰',
#  '각',
#  '노트',
#  '사용',
#  '케이스',
#  '진짜',
#  '각도',
#  '조절',
#  '조금',
#  '점',
#  '생각',
#  '옵션',
#  '파우치',
#  '얼마나',
#  '구매',
#  '사용',
#  '총',
#  '개',
#  '사용',
#  '전',
#  '물티슈',
#  '프린트',
#  '번',
#  '교환',
#  '그냥',
#  '모기',
#  '선물',
#  '준',
#  '사람',
#  '사람',
#  '모두',
#  '심플',
#  '재질',
#  '워',
#  '살',
#  '자국',
#  '베이',
#  '폭망',
#  '재',
#  '확인',
#  '안',
#  '제',
#  '잘못',
#  '참고',
#  '싱글',
#  '세트',
#  '퀸',
#  '세트',
#  '고정',
#  '떡',
#  '처럼',
#  '걱정',
#  '주문',
#  '카페',
#  '진짜',
#  '배송',
#  '엄',
#  '절수',
#  '밑',
#  '서랍',
#  '금방',
#  '물어',
#  '봣',
#  '전화',
#  '톡',
#  '보냇',
#  '오후',
#  '답',
#  '뭐',
#  '상담시',
#  '좀',
#  '답장',
#  '색도',
#  '이불',
#  '네이비',
#  '색상',
#  '조금',
#  '굿',
#  '역시',
#  '보람',
#  '제품',
#  '이군',
#  '퀄리티',
#  '좀',
#  '손',
#  '이따',
#  '약간',
#  '설치',
#  '반품',
#  '그냥',
#  '피부',
#  '트러블',
#  '더',
#  '몸',
#  '사용',
#  '몸',
#  '뾰',
#  '루지',
#  '일',
#  '발',
#  '멍',
#  '고통',
#  '컨디션',
#  '더',
#  '패기',
#  '처분',
#  '사람',
#  '기전',
#  '결정',
#  '참고',
#  '전',
#  '평발',
#  '이유식',
#  '초기',
#  '사용',
#  '후기',
#  '보고',
#  '구매',
#  '사이즈',
#  '실리콘',
#  '재질',
#  '사이즈',
#  '자마자',
#  '뎅',
#  '좀',
#  '애가',
#  '생각',
#  '나중',
#  '먼지',
#  '식물',
#  '물건',
#  '흠',
#  '정력',
#  '처음',
#  '사용',
#  '땐',
#  '찌꺼기',
#  '사용',
#  '지멘스',
#  '다시',
#  '체형',
#  '흡착',
#  '식판',
#  '거',
#  '애기',
#  '자꾸',
#  '짱구',
#  '소개',
#  '이용',
#  '저번',
#  '거',
#  '또',
#  '기름',
#  '질겨',
#  '상품',
#  '주시',
#  '고객',
#  '명',
#  '이제',
#  '이용',
#  '연휴',
#  '때',
#  '시켯더',
#  '연휴',
#  '때',
#  '달',
#  '왓네',
#  '연락',
#  '택배',
#  '회사',
#  '연락',
#  '상품',
#  '별로',
#  '저번',
#  '삿는데',
#  '역시',
#  '핸들',
#  '때',
#  '배송',
#  '설명',
#  '배송',
#  '짱짱',
#  '돌뼈',
#  '최고',
#  '안',
#  '패드',
#  '자꾸',
#  '가게',
#  '사용',
#  '피',
#  '때',
#  '사이즈',
#  '구매',
#  '언제',
#  '프린트',
#  '포인트',
#  '보온',
#  '기능',
#  '짱',
#  '최고',
#  '강추',
#  '시간',
#  '접착',
#  '그대로',
#  '지퍼',
#  '한번',
#  '장남',
#  '최악',
#  '무게',
#  '나가요',
#  '마제',
#  '애',
#  '선택',
#  '가격',
#  '대비',
#  '접해',
#  '앞',
#  '구성',
#  '점',
#  '이기',
#  '구입',
#  '생각',
#  '흰색',
#  '아기',
#  '재질',
#  '항상',
#  '애용',
#  '리뷰',
#  '기도',
#  '뭐',
#  '것',
#  '배송',
#  '아주',
#  '밑위',
#  '좀더',
#  '수딩젤',
#  '오히려',
#  '더',
#  '크림',
#  '보습',
#  '페넬로페',
#  '세자',
#  '린',
#  '제품',
#  '구매',
#  '세자',
#  '린',
#  '마지막',
#  '팩',
#  '전',
#  '도착',
#  '실망',
#  '요',
#  '마무리',
#  '처리',
#  '사이즈',
#  '크게',
#  '통',
#  '아주',
#  '강추',
#  '센치',
#  '토퍼',
#  '사용',
#  '사이즈',
#  '배송',
#  '좀',
#  '몇번',
#  '거',
#  '환불',
#  '건',
#  '처리',
#  '두께',
#  '생각',
#  '햇',
#  '더',
#  '다음',
#  '갈색',
#  '배송',
#  '마음',
#  '사진',
#  '다른',
#  '증정',
#  '품',
#  '변경',
#  '미리',
#  '고지',
#  '항상',
#  '구매',
#  '곳',
#  '가격',
#  '대비',
#  '최고',
#  '죵',
#  '스',
#  '최공',
#  '바람',
#  '크기',
#  '생각',
#  '심',
#  '입안',
#  '선물',
#  '요',
#  '필수',
#  '꼭',
#  '구매',
#  '촉감',
#  '무',
#  '끌',
#  '별로',
#  '반품',
#  '그냥',
#  '여유',
#  '가성',
#  '비',
#  '최고',
#  '불도',
#  '여기',
#  '상품',
#  '지인',
#  '추천',
#  '문해',
#  '봣',
#  '회사',
#  '자주',
#  '주문',
#  '좀',
#  '그냥',
#  '배송',
#  '설치',
#  '화질',
#  '아기',
#  '목욕',
#  '안전',
#  '바',
#  '세면대',
#  '설치',
#  '시트',
#  '밑',
#  '고정',
#  '다리',
#  '좀',
#  '배송',
#  '배송',
#  '상품',
#  '사진',
#  '무게',
#  '지탱',
#  '못햎',
#  '자꾸',
#  '생각',
#  '외로',
#  '모기',
#  '고구마',
#  '외이케',
#  '말랏나',
#  '나하',
#  '려',
#  '바빠깜팍',
#  '햇',
#  '번',
#  '한적',
#  '적업',
#  '사이즈',
#  '정도',
#  '중',
#  '이',
#  '중',
#  '바코드',
#  '왜',
#  '손상',
#  '건',
#  '제품',
#  '항상',
#  '용량',
#  '박스',
#  '사이즈',
#  '체크',
#  '제품',
#  '주',
#  '배송',
#  '날짜',
#  '칼',
#  '요',
#  '이사',
#  '날',
#  '배달',
#  '설치',
#  '늘',
#  '여름',
#  '지속',
#  '좀',
#  '가격',
#  '상품',
#  '가치',
#  '크기',
#  '입사',
#  '크기',
#  '은',
#  '상',
#  '이건',
#  '좀',
#  '정가',
#  '할인',
#  '액',
#  '하나',
#  '효과',
#  '일도',
#  '기분',
#  '가방',
#  '실리콘',
#  '좀',
#  '그거',
#  '괜찬',
#  '거',
#  '배송',
#  '역시',
#  '헤라',
#  '아이',
#  '아이스크림',
#  '실리콘',
#  '빼기',
#  '어이',
#  '셈',
#  '개',
#  '비어',
#  '작업',
#  '움',
#  '효과',
#  '체감',
#  '슬림핏',
#  '레귤러네',
#  '왜',
#  '승무원',
#  '스프레이',
#  '짱',
#  '흡수',
#  '광택',
#  '연어초밥',
#  '연어',
#  '내일',
#  '연어',
#  '스테이크',
#  '까나페',
#  '해',
#  '상',
#  '판이',
#  '조금',
#  '일부러',
#  '여름',
#  '배송',
#  '빨랏어',
#  '매번',
#  '거',
#  '가격',
#  '배',
#  '머리',
#  '결',
#  '트리트먼트',
#  '거',
#  '럼',
#  '탈색',
#  '갈색',
#  '모',
#  '파란색',
#  '전혀',
#  '짐',
#  '핀',
#  '부분',
#  '골드',
#  '알러지',
#  '반응',
#  '나름',
#  '가격',
#  '퀄리티',
#  '배송',
#  '레깅스',
#  '밑단',
#  '마무리',
#  '성함',
#  '수트',
#  '화면',
#  '주황색',
#  '배송',
#  '좀',
#  '상자',
#  '제품',
#  '사용설명서',
#  '남자',
#  '여자',
#  '구성',
#  '승',
#  '능',
#  '디',
#  '슴',
#  '상품',
#  '맘',
#  '배송',
#  '기간',
#  '두께',
#  '감',
#  '완전',
#  '별로',
#  '사용',
#  '법도',
#  '중국어',
#  '영어',
#  '심지어',
#  '사이트',
#  '용법',
#  '도',
#  '며칠',
#  '그냥',
#  '용도',
#  '사용',
#  '목적',
#  '알람',
#  '소리',
#  '진짜',
#  '생각',
#  '굿',
#  '년',
#  '것',
#  '배송',
#  '편이',
#  '전보',
#  '좀더',
#  '금방',
#  '더',
#  '무른편',
#  '것',
#  '선물',
#  '용이',
#  '꼭꼭',
#  '아이',
#  '마음',
#  '개',
#  '제',
#  '개',
#  '아이',
#  '용',
#  '아예',
#  '로고',
#  '불량',
#  '이',
#  '뭔가',
#  '검수',
#  '안',
#  '제',
#  '이제',
#  '칸막이',
#  '규격',
#  '높이',
#  '물건',
#  '성의',
#  '제품',
#  '포장',
#  '상태',
#  '보고',
#  '구입',
#  '마음',
#  '맛',
#  '착',
#  '레깅스',
#  '색상',
#  '담번',
#  '꼭',
#  '추가',
#  '구입',
#  '겨울',
#  '커버',
#  '배송',
#  '행사',
#  '배송',
#  '용량',
#  '리가',
#  '좀',
#  '노트',
#  '충전',
#  '칸',
#  '무선',
#  '연결',
#  '시간',
#  '좀',
#  '유선',
#  '충전',
#  '충전기',
#  '무슨',
#  '소리',
#  '사용',
#  '별로',
#  '지장',
#  '배송',
#  '서비스',
#  '매우',
#  '일방',
#  '스케줄',
#  '통보',
#  '배',
#  '라식',
#  '처음',
#  '생각',
#  '정말',
#  '다시',
#  '생폰',
#  '상태',
#  '아이',
#  '배송',
#  '생각',
#  '흡수',
#  '장말',
#  '엄마',
#  '아빠',
#  '보',
#  '번창',
#  '한쪽',
#  '버',
#  '녹',
#  '이슬',
#  '끈',
#  '이임',
#  '돈',
#  '조금',
#  '상황',
#  '볼트',
#  '배달',
#  '별루임',
#  '그냥',
#  '이유',
#  '흉터',
#  '반응',
#  '포장',
#  '하나',
#  '하나',
#  '포장',
#  '곳',
#  '레드',
#  '몽',
#  '판매',
#  '구매',
#  '레드',
#  '하나',
#  '나머지',
#  '전부',
#  '레드',
#  '전부',
#  '레드',
#  '도도',
#  '지속',
#  '좀',
#  '접이식',
#  '수납',
#  '가방',
#  '다만',
#  '철',
#  '가방',
#  '하나',
#  '더',
#  '밤',
#  '키',
#  '를',
#  '마지막',
#  '왜',
#  '가요',
#  '상한',
#  '대형',
#  '마트',
#  '구매',
#  '발품',
#  '다가',
#  '네이버',
#  '페이',
#  '상품',
#  '제',
#  '때',
#  '그냥',
#  '때',
#  '국물',
#  '마음',
#  '마음',
#  '생각',
#  '크기',
#  '당황',
#  '다음',
#  '또',
#  '구매',
#  '좀',
#  '롱롱',
#  '치마',
#  '보지',
#  '일단',
#  '배송',
#  '용도',
#  '절대',
#  '안',
#  '살',
#  '후회',
#  '고급',
#  '세트',
#  '가리비',
#  '하나',
#  '실망',
#  '백상',
#  '합',
#  '추가',
#  '문의',
#  '글',
#  '답',
#  '리뷰',
#  '닭',
#  '특유',
#  '맛',
#  '별로',
#  '침대',
#  '밑',
#  '수납',
#  '사이즈',
#  '싱크',
#  '안',
#  '문',
#  '안',
#  '양도',
#  '신선도',
#  '별로',
#  '무난',
#  '미스',
#  '주문',
#  '예전',
#  '무지',
#  '벤치',
#  '때',
#  '오',
#  '착오',
#  '배송',
#  '건',
#  '상담',
#  '재배',
#  '송해',
#  '상품',
#  '배송',
#  '품질',
#  '아주',
#  '거래',
#  '사이즈',
#  '답',
#  '배송',
#  '하루',
#  '더',
#  '늘',
#  '목',
#  '뿌러',
#  '진',
#  '검수',
#  '아침식사',
#  '비개',
#  '너',
#  '무',
#  '입구',
#  '조금',
#  '거',
#  '재질',
#  '배송',
#  '모두',
#  ...]

# %% [markdown]
# ## 4) 데이터 탐색

# %%
count = Counter(reviews_N)
count
# Out:
# Counter({'배송': 1413,
#          '구매': 836,
#          '사용': 664,
#          '제품': 620,
#          '그냥': 595,
#          '가격': 556,
#          '좀': 547,
#          '생각': 546,
#          '주문': 511,
#          '맛': 480,
#          '때': 430,
#          '더': 410,
#          '별로': 404,
#          '사이즈': 387,
#          '것': 379,
#          '포장': 341,
#          '개': 338,
#          '상품': 333,
#          '거': 319,
#          '냄새': 308,
#          '정말': 297,
#          '요': 288,
#          '하나': 279,
#          '부분': 262,
#          '진짜': 248,
#          '안': 242,
#          '조금': 236,
#          '반품': 231,
#          '구입': 229,
#          '아주': 217,
#          '또': 214,
#          '정도': 211,
#          '느낌': 207,
#          '아이': 203,
#          '완전': 199,
#          '다시': 195,
#          '맘': 195,
#          '사진': 194,
#          '디자인': 173,
#          '색상': 170,
#          '처음': 169,
#          '효과': 169,
#          '비': 166,
#          '제': 164,
#          '저': 164,
#          '마음': 162,
#          '이': 156,
#          '용': 155,
#          '선물': 154,
#          '다른': 154,
#          '걸': 153,
#          '크기': 151,
#          '대비': 148,
#          '바로': 143,
#          '보고': 143,
#          '항상': 142,
#          '한번': 140,
#          '상태': 140,
#          '추천': 139,
#          '교환': 138,
#          '해': 136,
#          '물건': 136,
#          '다음': 136,
#          '후': 134,
#          '전': 131,
#          '돈': 131,
#          '가성': 127,
#          '향': 127,
#          '박스': 126,
#          '만족': 125,
#          '계속': 123,
#          '이번': 123,
#          '듯': 123,
#          '실망': 122,
#          '수': 121,
#          '집': 119,
#          '설치': 119,
#          '색': 118,
#          '옷': 115,
#          '곳': 114,
#          '조립': 110,
#          '번': 107,
#          '달': 106,
#          '재질': 105,
#          '역시': 105,
#          '뭐': 104,
#          '여기': 102,
#          '감': 102,
#          '불량': 101,
#          '왜': 101,
#          '마감': 101,
#          '택배': 99,
#          '확인': 97,
#          '아기': 97,
#          '물': 97,
#          '못': 94,
#          '손': 93,
#          '기분': 93,
#          '분': 92,
#          '약간': 90,
#          '판매': 90,
#          '최고': 89,
#          '날': 89,
#          '줄': 89,
#          '먹기': 88,
#          '살짝': 88,
#          '시간': 86,
#          '점': 84,
#          '일단': 84,
#          '착용': 84,
#          '알': 83,
#          '하루': 82,
#          '사서': 81,
#          '이건': 81,
#          '고정': 78,
#          '통': 78,
#          '후기': 78,
#          '굿': 77,
#          '설명': 75,
#          '매우': 75,
#          '길이': 74,
#          '사람': 74,
#          '쓰기': 74,
#          '신경': 74,
#          '먼지': 72,
#          '도': 71,
#          '추가': 71,
#          '때문': 71,
#          '살': 69,
#          '앞': 69,
#          '늘': 68,
#          '걱정': 68,
#          '리뷰': 68,
#          '거의': 68,
#          '소리': 67,
#          '건': 67,
#          '질': 67,
#          '연락': 66,
#          '빨': 66,
#          '최악': 66,
#          '여름': 66,
#          '머리': 66,
#          '문제': 66,
#          '달라': 66,
#          '금방': 65,
#          '도착': 65,
#          '처리': 65,
#          '나': 65,
#          '제대로': 65,
#          '애': 64,
#          '듭니': 64,
#          '말': 63,
#          '햇': 63,
#          '다리': 63,
#          '구멍': 63,
#          '지금': 61,
#          '여': 61,
#          '화면': 60,
#          '자주': 60,
#          '충전': 60,
#          '끈': 60,
#          '원래': 60,
#          '데': 59,
#          '재': 58,
#          '품질': 58,
#          '세탁': 58,
#          '모두': 57,
#          '중': 57,
#          '가방': 57,
#          '케이스': 56,
#          '참고': 56,
#          '환불': 56,
#          '두번째': 56,
#          '구': 54,
#          '음': 54,
#          '이용': 53,
#          '전혀': 53,
#          '다만': 53,
#          '함': 53,
#          '색깔': 53,
#          '의사': 53,
#          '뚜껑': 53,
#          '기대': 53,
#          '기사': 52,
#          '잘못': 52,
#          '커버': 52,
#          '커서': 52,
#          '자꾸': 51,
#          '그대로': 50,
#          '문의': 50,
#          '거리': 50,
#          '그': 50,
#          '정리': 50,
#          '나사': 50,
#          '임': 49,
#          '의자': 49,
#          '피부': 49,
#          '힘': 49,
#          '오늘': 49,
#          '발': 48,
#          '꼭': 48,
#          '절대': 48,
#          '입': 48,
#          '이상': 48,
#          '자체': 48,
#          '제일': 48,
#          '매번': 47,
#          '엄마': 47,
#          '보': 47,
#          '무난': 47,
#          '막': 47,
#          '운동': 47,
#          '일주일': 47,
#          '기한': 47,
#          '일': 46,
#          '몇번': 46,
#          '덜': 46,
#          '게': 46,
#          '티': 45,
#          '후회': 45,
#          '얼굴': 45,
#          '고민': 45,
#          '바닥': 45,
#          '고무': 44,
#          '끝': 44,
#          '유통': 44,
#          '친구': 43,
#          '상자': 43,
#          '안나': 42,
#          '면': 42,
#          '이불': 42,
#          '아들': 42,
#          '뒤': 42,
#          '신발': 42,
#          '전화': 41,
#          '무게': 41,
#          '접착': 41,
#          '크게': 41,
#          '기존': 41,
#          '고장': 41,
#          '소재': 41,
#          '밑': 40,
#          '손잡이': 40,
#          '일반': 40,
#          '눈': 40,
#          '자마자': 40,
#          '번창': 40,
#          '보관': 40,
#          '가지': 40,
#          '좀더': 39,
#          '이유': 39,
#          '해도': 39,
#          '중간': 39,
#          '양': 39,
#          '차이': 39,
#          '자국': 38,
#          '배': 38,
#          '한쪽': 38,
#          '키': 38,
#          '고기': 38,
#          '쪽': 38,
#          '플라스틱': 38,
#          '습': 38,
#          '배송비': 38,
#          '비닐': 38,
#          '퀄리티': 37,
#          '애기': 37,
#          '기도': 37,
#          '두께': 37,
#          '바': 37,
#          '편이': 37,
#          '가요': 37,
#          '물이': 37,
#          '팩': 36,
#          '용량': 36,
#          '블랙': 36,
#          '원단': 36,
#          '위': 36,
#          '나무': 36,
#          '냉동': 36,
#          '김치': 36,
#          '은': 35,
#          '무슨': 35,
#          '모양': 35,
#          '등': 35,
#          '작고': 35,
#          '핑크': 35,
#          '보기': 34,
#          '구성': 34,
#          '무': 34,
#          '주': 34,
#          '예전': 34,
#          '인터넷': 34,
#          '남편': 34,
#          '실제': 34,
#          '속': 34,
#          '엉망': 33,
#          '서비스': 33,
#          '기름': 33,
#          '품': 33,
#          '고구마': 33,
#          '뭔가': 33,
#          '예정': 33,
#          '장': 33,
#          '양말': 33,
#          '우리': 33,
#          '이제': 32,
#          '기능': 32,
#          '선택': 32,
#          '용도': 32,
#          '연결': 32,
#          '마리': 32,
#          '사지': 32,
#          '차': 32,
#          '사은': 32,
#          '허리': 32,
#          '누가': 32,
#          '자': 32,
#          '파손': 32,
#          '솜': 32,
#          '사': 32,
#          '이즈': 31,
#          '흰색': 31,
#          '마트': 31,
#          '신랑': 31,
#          '편': 31,
#          '전체': 31,
#          '비교': 31,
#          '시': 31,
#          '화이트': 31,
#          '감사': 31,
#          '로': 31,
#          '부모님': 31,
#          '스티커': 31,
#          '세트': 30,
#          '색도': 30,
#          '저번': 30,
#          '패드': 30,
#          '높이': 30,
#          '목': 30,
#          '너': 30,
#          '테이프': 30,
#          '마스크': 30,
#          '벌써': 30,
#          '내': 30,
#          '기스': 30,
#          '우선': 30,
#          '봉': 30,
#          '필름': 30,
#          '거품': 29,
#          '지인': 29,
#          '글': 29,
#          '평': 29,
#          '걸이': 29,
#          '털': 29,
#          '붙이': 29,
#          '산': 29,
#          '폭': 29,
#          '몇개': 29,
#          '반': 29,
#          '작동': 29,
#          '바지': 28,
#          '별루': 28,
#          '젤': 28,
#          '조절': 28,
#          '서랍': 28,
#          '몸': 28,
#          '움': 28,
#          '검수': 28,
#          '수납': 28,
#          '밤': 28,
#          '문': 28,
#          '간식': 28,
#          '덕분': 28,
#          '무엇': 28,
#          '별': 28,
#          '영': 28,
#          '담': 28,
#          '선': 28,
#          '강아지': 28,
#          '가루': 28,
#          '만': 28,
#          '쿠션': 28,
#          '옆': 27,
#          '흠': 27,
#          '바람': 27,
#          '지속': 27,
#          '양도': 27,
#          '그닥': 27,
#          '봉지': 27,
#          '보이': 27,
#          '매트': 27,
#          '가족': 27,
#          '이해': 27,
#          '볼': 27,
#          '회사': 26,
#          '떡': 26,
#          '대충': 26,
#          '이틀': 26,
#          '성능': 26,
#          '우유': 26,
#          '실': 26,
#          '쓰레기': 26,
#          '제거': 26,
#          '답': 25,
#          '지퍼': 25,
#          '배달': 25,
#          '옴': 25,
#          '종이': 25,
#          '정품': 25,
#          '신청': 25,
#          '니': 25,
#          '려고': 25,
#          '사고': 25,
#          '요즘': 25,
#          '소음': 25,
#          '입맛': 25,
#          '대박': 24,
#          '강추': 24,
#          '겨울': 24,
#          '볼트': 24,
#          '를': 24,
#          '보지': 24,
#          '매일': 24,
#          '밥': 24,
#          '끼': 24,
#          '부위': 24,
#          '겉': 24,
#          '공간': 24,
#          '곰팡이': 24,
#          '보통': 24,
#          '아침': 24,
#          '컬러': 23,
#          '남자': 23,
#          '땐': 23,
#          '나중': 23,
#          '미리': 23,
#          '상': 23,
#          '아예': 23,
#          '뻑뻑': 23,
#          '개월': 23,
#          '트': 23,
#          '해외': 23,
#          '평이': 23,
#          '루': 23,
#          '차라리': 23,
#          '워낙': 23,
#          '광고': 23,
#          '브랜드': 22,
#          '핏': 22,
#          '대신': 22,
#          '짱': 22,
#          '나름': 22,
#          '강': 22,
#          '온': 22,
#          '안쪽': 22,
#          '부착': 22,
#          '적극': 22,
#          '혼자': 22,
#          '관리': 22,
#          '전이': 22,
#          '여행': 22,
#          '실밥': 22,
#          '선반': 22,
#          '저녁': 22,
#          '주시': 21,
#          '스': 21,
#          '작업': 21,
#          '흡수': 21,
#          '짐': 21,
#          '고급': 21,
#          '교체': 21,
#          '새': 21,
#          '유리': 21,
#          '평소': 21,
#          '도움': 21,
#          '기': 21,
#          '딸': 21,
#          '확정': 21,
#          '촉감': 20,
#          '불': 20,
#          '고객': 20,
#          '마무리': 20,
#          '여자': 20,
#          '침대': 20,
#          '거치': 20,
#          '건강': 20,
#          '주변': 20,
#          '장난': 20,
#          '다행': 20,
#          '방': 20,
#          '제발': 20,
#          '자극': 20,
#          '업체': 20,
#          '껍질': 20,
#          '단': 20,
#          '오징어': 20,
#          '먼저': 20,
#          '고생': 20,
#          '소스': 20,
#          '애용': 19,
#          '직접': 19,
#          '가슴': 19,
#          '요청': 19,
#          '양쪽': 19,
#          '건가': 19,
#          '머': 19,
#          '무거워': 19,
#          '세척': 19,
#          '어깨': 19,
#          '값': 19,
#          '질도': 19,
#          '얼마': 19,
#          '만해': 19,
#          '열': 19,
#          '무료': 19,
#          '중이': 19,
#          '일리': 19,
#          '흠집': 19,
#          '약': 19,
#          '어머니': 19,
#          '벽': 19,
#          '가장': 19,
#          '트러블': 18,
#          '크림': 18,
#          '모': 18,
#          '행사': 18,
#          '발송': 18,
#          '양념': 18,
#          '리': 18,
#          '한참': 18,
#          '그레이': 18,
#          '문자': 18,
#          '터치': 18,
#          '용기': 18,
#          '굿굿': 18,
#          '안경': 18,
#          '스타일': 18,
#          '기본': 18,
#          '겹': 18,
#          '망': 18,
#          '시계': 18,
#          '술': 18,
#          '여기저기': 18,
#          '부품': 18,
#          '위해': 18,
#          '테': 18,
#          '인식': 18,
#          '빛': 18,
#          '꽉': 18,
#          '배터리': 18,
#          '김': 18,
#          '개인': 18,
#          '짜증': 18,
#          '당황': 17,
#          '코팅': 17,
#          '바퀴': 17,
#          '모서리': 17,
#          '옵션': 17,
#          '심플': 17,
#          '삿는데': 17,
#          '오히려': 17,
#          '오': 17,
#          '개봉': 17,
#          '경우': 17,
#          '내용물': 17,
#          '지방': 17,
#          '인지': 17,
#          '방법': 17,
#          '안해': 17,
#          '거울': 17,
#          '귀': 17,
#          '네': 17,
#          '수고': 17,
#          '모자': 17,
#          '품절': 17,
#          '그것': 17,
#          '버튼': 17,
#          '한지': 17,
#          '색감': 17,
#          '중국산': 17,
#          '방지': 17,
#          '자석': 17,
#          '엉덩이': 17,
#          '청소': 17,
#          '식': 17,
#          '정사': 17,
#          '고해': 17,
#          '종류': 17,
#          '금': 17,
#          '로션': 17,
#          '사면': 17,
#          '시작': 17,
#          '라면': 17,
#          '타': 17,
#          '실리콘': 16,
#          '여유': 16,
#          '화질': 16,
#          '전부': 16,
#          '다가': 16,
#          '병': 16,
#          '깜짝': 16,
#          '하니': 16,
#          '대가': 16,
#          '보풀': 16,
#          '타이': 16,
#          '이전': 16,
#          '꽤': 16,
#          '유': 16,
#          '부담': 16,
#          '욤': 16,
#          '티나': 16,
#          '지난번': 16,
#          '거나': 16,
#          '다해': 16,
#          '허벅지': 16,
#          '속도': 16,
#          '포': 16,
#          '확': 16,
#          '모델': 16,
#          '고리': 16,
#          '혹시': 16,
#          '싸구려': 16,
#          '손질': 16,
#          '망치': 16,
#          '신축': 15,
#          '그거': 15,
#          '기간': 15,
#          '며칠': 15,
#          '나머지': 15,
#          '국물': 15,
#          '쏙': 15,
#          '순간': 15,
#          '세번': 15,
#          '땀': 15,
#          '된거': 15,
#          '커피': 15,
#          '답변': 15,
#          '만큼': 15,
#          '장갑': 15,
#          '건데': 15,
#          '개선': 15,
#          '사실': 15,
#          '콩': 15,
#          '화장실': 15,
#          '책상': 15,
#          '점점': 15,
#          '그린': 15,
#          '뽁뽁': 15,
#          '탓': 15,
#          '펜': 15,
#          '손가락': 15,
#          '핑크색': 15,
#          '아가': 15,
#          '물질': 15,
#          '게임': 15,
#          '남': 15,
#          '가위': 15,
#          '가죽': 15,
#          '용감': 15,
#          '안보': 15,
#          '수준': 15,
#          '스크래치': 15,
#          '바느질': 14,
#          '계란': 14,
#          '생기': 14,
#          '물티슈': 14,
#          '보습': 14,
#          '마지막': 14,
#          '필수': 14,
#          '시트': 14,
#          '연어': 14,
#          '디': 14,
#          '닭': 14,
#          '무지': 14,
#          '상담': 14,
#          '입구': 14,
#          '접': 14,
#          '고': 14,
#          '심해': 14,
#          '검색': 14,
#          '아래': 14,
#          '삿': 14,
#          '어디': 14,
#          '중국': 14,
#          '저희': 14,
#          '검은색': 14,
#          '제작': 14,
#          '단점': 14,
#          '코': 14,
#          '치수': 14,
#          '번호': 14,
#          '가끔': 14,
#          '군데': 14,
#          '진동': 14,
#          '불편': 14,
#          '난리': 14,
#          '해주시': 14,
#          '보호': 14,
#          '분리': 14,
#          '칫솔': 14,
#          '손톱': 14,
#          '베란다': 14,
#          '정상': 14,
#          '활용': 14,
#          '빨래': 14,
#          '무척': 14,
#          '브라운': 14,
#          '런가': 14,
#          '작': 14,
#          '물품': 14,
#          '신고': 14,
#          '채': 14,
#          '센터': 14,
#          '세': 14,
#          '딸기': 14,
#          '어른': 14,
#          '얼음': 14,
#          '누락': 13,
#          '팬티': 13,
#          '려': 13,
#          '성분': 13,
#          '겨우': 13,
#          '살껄': 13,
#          '워': 13,
#          '사이트': 13,
#          '네이버': 13,
#          '빨대': 13,
#          '연습': 13,
#          '날씨': 13,
#          '한장': 13,
#          '폰': 13,
#          '내용': 13,
#          '휘': 13,
#          '그릇': 13,
#          '젖병': 13,
#          '핸드폰': 13,
#          '어보': 13,
#          '취소': 13,
#          '하자': 13,
#          '자리': 13,
#          '이안': 13,
#          '울': 13,
#          '분위기': 13,
#          '둘': 13,
#          '청': 13,
#          '다이어트': 13,
#          '불만': 13,
#          '이후': 13,
#          '아이스팩': 13,
#          '음식': 13,
#          '받침': 13,
#          '만족도': 13,
#          '땜': 13,
#          '맘에듭니': 13,
#          '어제': 13,
#          '수분': 13,
#          '금액': 13,
#          '첨': 13,
#          '재고': 13,
#          '즙': 13,
#          '드네': 13,
#          '대한': 13,
#          '첫': 13,
#          '검정색': 13,
#          '지연': 13,
#          '주머니': 13,
#          '방수': 13,
#          '얼룩': 13,
#          '실용': 12,
#          '베이지': 12,
#          '사장': 12,
#          '화장': 12,
#          '정력': 12,
#          '비지': 12,
#          '결정': 12,
#          '애가': 12,
#          '언제': 12,
#          '포인트': 12,
#          '심': 12,
#          '어이': 12,
#          '완료': 12,
#          '수량': 12,
#          '및': 12,
#          '에어': 12,
#          '단맛': 12,
#          '는걸': 12,
#          '보임': 12,
#          '상처': 12,
#          '거기': 12,
#          '보시': 12,
#          '야채': 12,
#          '천원': 12,
#          '실패': 12,
#          '수령': 12,
#          '생일': 12,
#          '쫌': 12,
#          '팔': 12,
#          '인테리어': 12,
#          '다소': 12,
#          '싸이': 12,
#          '사무실': 12,
#          '기고': 12,
#          '벌레': 12,
#          '케이블': 12,
#          '최저': 12,
#          '틀': 12,
#          '컵': 12,
#          '기장': 12,
#          '뿌리': 12,
#          '다이소': 12,
#          '주름': 12,
#          '체험': 12,
#          '대요': 12,
#          '남아': 12,
#          '응대': 12,
#          '테두리': 12,
#          '정': 12,
#          '달이': 12,
#          '쭉': 12,
#          '검정': 12,
#          '휴대': 12,
#          '기계': 12,
#          '난': 12,
#          '판': 12,
#          '캡': 12,
#          '투명': 12,
#          '압축': 12,
#          '표기': 12,
#          '두': 12,
#          '취향': 12,
#          '살이': 12,
#          '동안': 12,
#          '샐러드': 12,
#          '추': 12,
#          '진공': 12,
#          '냉장고': 12,
#          '전달': 11,
#          '위생': 11,
#          '장사': 11,
#          '아이보리': 11,
#          '베이': 11,
#          '안전': 11,
#          '날짜': 11,
#          '판이': 11,
#          '일부러': 11,
#          '무선': 11,
#          '충전기': 11,
#          '레드': 11,
#          '대형': 11,
#          '합': 11,
#          '표면': 11,
#          '가운데': 11,
#          '어찌': 11,
#          '세제': 11,
#          '어': 11,
#          '수정': 11,
#          '회색': 11,
#          '오프라인': 11,
#          '몇': 11,
#          '필요': 11,
#          '펄': 11,
#          '내부': 11,
#          '건전지': 11,
#          '진심': 11,
#          '잠깐': 11,
#          '원목': 11,
#          '박음질': 11,
#          '새우': 11,
#          '지네': 11,
#          '샘플': 11,
#          '실물': 11,
#          '이미지': 11,
#          '가구': 11,
#          '요리': 11,
#          '풀': 11,
#          '봄': 11,
#          '박아': 11,
#          '이나': 11,
#          '조': 11,
#          '똑': 11,
#          '살걸': 11,
#          '측정': 11,
#          '이면': 11,
#          '내장': 11,
#          '반찬': 11,
#          '서도': 11,
#          '자동': 11,
#          '손목': 11,
#          '여러': 11,
#          '뻔': 11,
#          '블라인드': 11,
#          '잠': 11,
#          '샴푸': 11,
#          '젤리': 11,
#          '일찍': 11,
#          '왓': 11,
#          '속옷': 10,
#          '치': 10,
#          '처': 10,
#          '실내': 10,
#          '듯해': 10,
#          '얼마나': 10,
#          '모기': 10,
#          '처럼': 10,
#          '봣': 10,
#          '멍': 10,
#          '명': 10,
#          '보온': 10,
#          '결': 10,
#          '칸': 10,
#          '철': 10,
#          '상한': 10,
#          '치마': 10,
#          '발림': 10,
#          '시기': 10,
#          '불량품': 10,
#          '바디': 10,
#          '조각': 10,
#          '발견': 10,
#          '천이': 10,
#          '무조건': 10,
#          '통화': 10,
#          '지지': 10,
#          '두피': 10,
#          '현상': 10,
#          '더니': 10,
#          '사시': 10,
#          '의심': 10,
#          '싹': 10,
#          '주일': 10,
#          '표시': 10,
#          '샤워': 10,
#          '수평': 10,
#          '뽁뽁이': 10,
#          '가로': 10,
#          '가시': 10,
#          '해먹': 10,
#          '매실': 10,
#          '자전거': 10,
#          '테이블': 10,
#          '인': 10,
#          '주신': 10,
#          '쇼핑': 10,
#          '팬': 10,
#          '조리': 10,
#          '마늘': 10,
#          '카메라': 10,
#          '프로': 10,
#          '장착': 10,
#          '개정': 10,
#          '말씀': 10,
#          '주말': 10,
#          '잉크': 10,
#          '작년': 10,
#          '해동': 10,
#          '로만': 10,
#          '포기': 10,
#          '도저히': 10,
#          '종일': 10,
#          '개별': 10,
#          '일회용': 10,
#          '집안': 10,
#          '지도': 10,
#          '렌즈': 10,
#          '원': 10,
#          '적': 10,
#          '타입': 10,
#          '유심': 10,
#          '주기': 10,
#          '분명': 10,
#          '도안': 10,
#          '밖': 10,
#          '역': 10,
#          '과일': 10,
#          '넣기': 10,
#          '이중': 10,
#          '층': 9,
#          '부직포': 9,
#          '완성': 9,
#          '이유식': 9,
#          '변경': 9,
#          '손상': 9,
#          '체크': 9,
#          '칼': 9,
#          '골드': 9,
#          '심지어': 9,
#          '착': 9,
#          '아빠': 9,
#          '프레임': 9,
#          '외관': 9,
#          '치약': 9,
#          '곱창': 9,
#          '일자': 9,
#          '닥': 9,
#          '머리카락': 9,
#          '활': 9,
#          '빵빵': 9,
#          '베개': 9,
#          '욕실': 9,
#          ...})

# %%
#막대 그래프로 나타내기 위해 자주 나타난 상위 100개 단어만 비교
word_count = dict()
for tag, counts in count.most_common(100):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# 배송 : 1413
# 구매 : 836
# 사용 : 664
# 제품 : 620
# 그냥 : 595
# 가격 : 556
# 생각 : 546
# 주문 : 511
# 별로 : 404
# 사이즈 : 387
# 포장 : 341
# 상품 : 333
# 냄새 : 308
# 정말 : 297
# 하나 : 279
# 부분 : 262
# 진짜 : 248
# 조금 : 236
# 반품 : 231
# 구입 : 229
# 아주 : 217
# 정도 : 211
# 느낌 : 207
# 아이 : 203
# 완전 : 199
# 다시 : 195
# 사진 : 194
# 디자인 : 173
# 색상 : 170
# 처음 : 169
# 효과 : 169
# 마음 : 162
# 선물 : 154
# 다른 : 154
# 크기 : 151
# 대비 : 148
# 바로 : 143
# 보고 : 143
# 항상 : 142
# 한번 : 140
# 상태 : 140
# 추천 : 139
# 교환 : 138
# 물건 : 136
# 다음 : 136
# 가성 : 127
# 박스 : 126
# 만족 : 125
# 계속 : 123
# 이번 : 123
# 실망 : 122
# 설치 : 119
# 조립 : 110
# 재질 : 105
# 역시 : 105
# 여기 : 102
# 불량 : 101
# 마감 : 101
# 택배 : 99
# 확인 : 97
# 아기 : 97
# 기분 : 93
# 약간 : 90

# %% [markdown]
# ## 5) 결과 시각화

# %%
font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family = font_name)

# %%
plt.figure(figsize = (12, 5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 75)
plt.show()

# %%
#워드 클라우드를 위해 자주 나타난 상위 400개의 단어를 가져옴

word_count = dict()
for tag, counts in count.most_common(400):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# 배송 : 1413
# 구매 : 836
# 사용 : 664
# 제품 : 620
# 그냥 : 595
# 가격 : 556
# 생각 : 546
# 주문 : 511
# 별로 : 404
# 사이즈 : 387
# 포장 : 341
# 상품 : 333
# 냄새 : 308
# 정말 : 297
# 하나 : 279
# 부분 : 262
# 진짜 : 248
# 조금 : 236
# 반품 : 231
# 구입 : 229
# 아주 : 217
# 정도 : 211
# 느낌 : 207
# 아이 : 203
# 완전 : 199
# 다시 : 195
# 사진 : 194
# 디자인 : 173
# 색상 : 170
# 처음 : 169
# 효과 : 169
# 마음 : 162
# 선물 : 154
# 다른 : 154
# 크기 : 151
# 대비 : 148
# 바로 : 143
# 보고 : 143
# 항상 : 142
# 한번 : 140
# 상태 : 140
# 추천 : 139
# 교환 : 138
# 물건 : 136
# 다음 : 136
# 가성 : 127
# 박스 : 126
# 만족 : 125
# 계속 : 123
# 이번 : 123
# 실망 : 122
# 설치 : 119
# 조립 : 110
# 재질 : 105
# 역시 : 105
# 여기 : 102
# 불량 : 101
# 마감 : 101
# 택배 : 99
# 확인 : 97
# 아기 : 97
# 기분 : 93
# 약간 : 90
# 판매 : 90
# 최고 : 89
# 먹기 : 88
# 살짝 : 88
# 시간 : 86
# 일단 : 84
# 착용 : 84
# 하루 : 82
# 사서 : 81
# 이건 : 81
# 고정 : 78
# 후기 : 78
# 설명 : 75
# 매우 : 75
# 길이 : 74
# 사람 : 74
# 쓰기 : 74
# 신경 : 74
# 먼지 : 72
# 추가 : 71
# 때문 : 71
# 걱정 : 68
# 리뷰 : 68
# 거의 : 68
# 소리 : 67
# 연락 : 66
# 최악 : 66
# 여름 : 66
# 머리 : 66
# 문제 : 66
# 달라 : 66
# 금방 : 65
# 도착 : 65
# 처리 : 65
# 제대로 : 65
# 듭니 : 64
# 다리 : 63
# 구멍 : 63
# 지금 : 61
# 화면 : 60
# 자주 : 60
# 충전 : 60
# 원래 : 60
# 품질 : 58
# 세탁 : 58
# 모두 : 57
# 가방 : 57
# 케이스 : 56
# 참고 : 56
# 환불 : 56
# 두번째 : 56
# 이용 : 53
# 전혀 : 53
# 다만 : 53
# 색깔 : 53
# 의사 : 53
# 뚜껑 : 53
# 기대 : 53
# 기사 : 52
# 잘못 : 52
# 커버 : 52
# 커서 : 52
# 자꾸 : 51
# 그대로 : 50
# 문의 : 50
# 거리 : 50
# 정리 : 50
# 나사 : 50
# 의자 : 49
# 피부 : 49
# 오늘 : 49
# 절대 : 48
# 이상 : 48
# 자체 : 48
# 제일 : 48
# 매번 : 47
# 엄마 : 47
# 무난 : 47
# 운동 : 47
# 일주일 : 47
# 기한 : 47
# 몇번 : 46
# 후회 : 45
# 얼굴 : 45
# 고민 : 45
# 바닥 : 45
# 고무 : 44
# 유통 : 44
# 친구 : 43
# 상자 : 43
# 안나 : 42
# 이불 : 42
# 아들 : 42
# 신발 : 42
# 전화 : 41
# 무게 : 41
# 접착 : 41
# 크게 : 41
# 기존 : 41
# 고장 : 41
# 소재 : 41
# 손잡이 : 40
# 일반 : 40
# 자마자 : 40
# 번창 : 40
# 보관 : 40
# 가지 : 40
# 좀더 : 39
# 이유 : 39
# 해도 : 39
# 중간 : 39
# 차이 : 39
# 자국 : 38
# 한쪽 : 38
# 고기 : 38
# 플라스틱 : 38
# 배송비 : 38
# 비닐 : 38
# 퀄리티 : 37
# 애기 : 37
# 기도 : 37
# 두께 : 37
# 편이 : 37
# 가요 : 37
# 물이 : 37
# 용량 : 36
# 블랙 : 36
# 원단 : 36
# 나무 : 36
# 냉동 : 36
# 김치 : 36
# 무슨 : 35
# 모양 : 35
# 작고 : 35
# 핑크 : 35
# 보기 : 34
# 구성 : 34
# 예전 : 34
# 인터넷 : 34
# 남편 : 34
# 실제 : 34
# 엉망 : 33
# 서비스 : 33
# 기름 : 33
# 고구마 : 33
# 뭔가 : 33
# 예정 : 33
# 양말 : 33
# 우리 : 33
# 이제 : 32
# 기능 : 32
# 선택 : 32
# 용도 : 32
# 연결 : 32
# 마리 : 32
# 사지 : 32
# 사은 : 32
# 허리 : 32
# 누가 : 32
# 파손 : 32
# 이즈 : 31
# 흰색 : 31
# 마트 : 31
# 신랑 : 31
# 전체 : 31
# 비교 : 31
# 화이트 : 31
# 감사 : 31
# 부모님 : 31
# 스티커 : 31
# 세트 : 30
# 색도 : 30
# 저번 : 30
# 패드 : 30
# 높이 : 30
# 테이프 : 30
# 마스크 : 30
# 벌써 : 30
# 기스 : 30
# 우선 : 30
# 필름 : 30
# 거품 : 29
# 지인 : 29
# 걸이 : 29
# 붙이 : 29
# 몇개 : 29
# 작동 : 29
# 바지 : 28
# 별루 : 28
# 조절 : 28
# 서랍 : 28
# 검수 : 28
# 수납 : 28
# 간식 : 28
# 덕분 : 28
# 무엇 : 28
# 강아지 : 28
# 가루 : 28
# 쿠션 : 28
# 바람 : 27
# 지속 : 27
# 양도 : 27
# 그닥 : 27
# 봉지 : 27
# 보이 : 27
# 매트 : 27
# 가족 : 27
# 이해 : 27
# 회사 : 26
# 대충 : 26
# 이틀 : 26
# 성능 : 26

# %%
wc = WordCloud(font_path, background_color = 'ivory', width = 800, height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize = (8, 8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# https://lovit.github.io/nlp/2018/04/17/word_cloud/
from PIL import Image
import numpy as np

mask = np.array(Image.open("shopping-cart-349544_1280.jpg"))

wordcloud = WordCloud(
    #폰트 경로를 지정하지 않으면 한글이 깨진다.
    font_path = "c:/Windows/fonts/malgun.ttf",
    width = 800,
    height = 800,
    background_color="white",
    mask = mask,
)

wordcloud = wordcloud.generate_from_frequencies(word_count)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ### 1) 별점 확인하기

# %%
ratings = total_data['ratings'].value_counts().sort_index()
ratings
# Out:
# ratings
# 1    36048
# 2    63989
# 4    18786
# 5    81177
# Name: count, dtype: int64

# %% [markdown]
# ### 2) 별점별 리뷰 확인하기

# %%
# 데이터가 너무 많아서 처리가 힘드므로, 1만 개의 리뷰만 가져옴
reviews = ''
for item in total_data[total_data['ratings']==1]['reviews'].iloc[0:10001]:
    reviews += re.sub(r'[^\w]', ' ', item) + ' '
# 품사 태깅
nlp = Okt()
reviews_N = nlp.nouns(reviews)
count = Counter(reviews_N)

# %%
#막대 그래프로 나타내기 위해 자주 나타난 상위 100개 단어만 비교
word_count = dict()
for tag, counts in count.most_common(100):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))

font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family = font_name)
plt.figure(figsize = (12, 5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 75)
plt.show()


#워드 클라우드를 위해 자주 나타난 상위 400개의 단어를 가져옴

word_count = dict()
for tag, counts in count.most_common(400):
    if(len(str(tag))>1):
        word_count[tag] = counts

# https://lovit.github.io/nlp/2018/04/17/word_cloud/
from PIL import Image
import numpy as np

mask = np.array(Image.open("shopping-cart-349544_1280.jpg"))

wordcloud = WordCloud(
    #폰트 경로를 지정하지 않으면 한글이 깨진다.
    font_path = "c:/Windows/fonts/malgun.ttf",
    width = 800,
    height = 800,
    background_color="white",
    mask = mask,
)

wordcloud = wordcloud.generate_from_frequencies(word_count)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# 배송 : 1645
# 구매 : 1016
# 사용 : 706
# 가격 : 615
# 제품 : 547
# 주문 : 537
# 생각 : 404
# 아주 : 379
# 사이즈 : 349
# 포장 : 336
# 정말 : 329
# 아이 : 294
# 항상 : 281
# 구입 : 255
# 선물 : 247
# 디자인 : 238
# 마음 : 230
# 추천 : 219
# 진짜 : 215
# 만족 : 214
# 가성 : 204
# 상품 : 203
# 조금 : 194
# 완전 : 192
# 하나 : 189
# 최고 : 173
# 색상 : 169
# 대비 : 167
# 다음 : 166
# 아기 : 150
# 처음 : 148
# 느낌 : 148
# 크기 : 147
# 역시 : 138
# 계속 : 137
# 바로 : 136
# 설치 : 133
# 냄새 : 133
# 효과 : 131
# 여기 : 125
# 사진 : 120
# 정도 : 120
# 보고 : 115
# 매우 : 107
# 듭니 : 103
# 쓰기 : 101
# 정리 : 101
# 걱정 : 100
# 한번 : 94
# 그냥 : 89
# 먹기 : 89
# 이번 : 88
# 다른 : 88
# 자주 : 87
# 물건 : 83
# 엄마 : 82
# 다시 : 82
# 조립 : 82
# 추가 : 80
# 이용 : 79
# 상태 : 77
# 두번째 : 77
# 매번 : 76
# 번창 : 75
# 하루 : 75
# 착용 : 75
# 친구 : 74
# 재질 : 74

# %%
#막대 그래프로 나타내기 위해 자주 나타난 상위 100개 단어만 비교
word_count = dict()
for tag, counts in count.most_common(100):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))

font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family = font_name)
plt.figure(figsize = (12, 5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 75)
plt.show()


#워드 클라우드를 위해 자주 나타난 상위 400개의 단어를 가져옴

word_count = dict()
for tag, counts in count.most_common(400):
    if(len(str(tag))>1):
        word_count[tag] = counts

# https://lovit.github.io/nlp/2018/04/17/word_cloud/
from PIL import Image
import numpy as np

mask = np.array(Image.open("shopping-cart-349544_1280.jpg"))

wordcloud = WordCloud(
    #폰트 경로를 지정하지 않으면 한글이 깨진다.
    font_path = "c:/Windows/fonts/malgun.ttf",
    width = 800,
    height = 800,
    background_color="white",
    mask = mask,
)

wordcloud = wordcloud.generate_from_frequencies(word_count)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# 배송 : 1530
# 사용 : 881
# 구매 : 794
# 가격 : 785
# 생각 : 717
# 제품 : 545
# 조금 : 465
# 주문 : 428
# 사이즈 : 419
# 포장 : 355
# 아이 : 314
# 대비 : 281
# 구입 : 266
# 아주 : 249
# 가성 : 246
# 상품 : 244
# 디자인 : 239
# 느낌 : 217
# 냄새 : 216
# 색상 : 214
# 부분 : 211
# 선물 : 207
# 크기 : 202
# 그냥 : 190
# 마음 : 184
# 정도 : 184
# 처음 : 182
# 정말 : 180
# 약간 : 179
# 효과 : 173
# 다만 : 172
# 하나 : 150
# 아기 : 148
# 설치 : 144
# 추천 : 144
# 만족 : 139
# 보고 : 136
# 사진 : 136
# 다음 : 135
# 다른 : 127
# 재질 : 127
# 살짝 : 126
# 먹기 : 126
# 항상 : 121
# 일단 : 121
# 조립 : 114
# 상태 : 112
# 진짜 : 109
# 쓰기 : 104
# 계속 : 104
# 한번 : 103
# 여름 : 103
# 바로 : 102
# 별로 : 96
# 무난 : 92
# 길이 : 89
# 걱정 : 87
# 색깔 : 87
# 정리 : 87
# 품질 : 85
# 이번 : 84
# 자주 : 82
# 물건 : 81
# 착용 : 81
# 후기 : 81
# 완전 : 79
# 다시 : 77
# 여기 : 74

# %%
#막대 그래프로 나타내기 위해 자주 나타난 상위 100개 단어만 비교
word_count = dict()
for tag, counts in count.most_common(100):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))

font_path = "c:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname = font_path).get_name()
matplotlib.rc('font', family = font_name)
plt.figure(figsize = (12, 5))
plt.xlabel('키워드')
plt.ylabel('빈도수')
plt.grid(True)
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = 75)
plt.show()


#워드 클라우드를 위해 자주 나타난 상위 400개의 단어를 가져옴

word_count = dict()
for tag, counts in count.most_common(400):
    if(len(str(tag))>1):
        word_count[tag] = counts

# https://lovit.github.io/nlp/2018/04/17/word_cloud/
from PIL import Image
import numpy as np

mask = np.array(Image.open("shopping-cart-349544_1280.jpg"))

wordcloud = WordCloud(
    #폰트 경로를 지정하지 않으면 한글이 깨진다.
    font_path = "c:/Windows/fonts/malgun.ttf",
    width = 800,
    height = 800,
    background_color="white",
    mask = mask,
)

wordcloud = wordcloud.generate_from_frequencies(word_count)
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# 배송 : 1232
# 그냥 : 1070
# 별로 : 819
# 제품 : 757
# 구매 : 708
# 사용 : 664
# 반품 : 548
# 주문 : 527
# 생각 : 456
# 상품 : 444
# 냄새 : 442
# 포장 : 397
# 진짜 : 389
# 부분 : 388
# 하나 : 379
# 가격 : 375
# 사이즈 : 361
# 정말 : 339
# 교환 : 322
# 정도 : 310
# 완전 : 296
# 최악 : 259
# 한번 : 258
# 처음 : 257
# 다시 : 257
# 실망 : 257
# 물건 : 227
# 불량 : 226
# 다른 : 222
# 사진 : 217
# 상태 : 214
# 보고 : 210
# 박스 : 202
# 확인 : 198
# 택배 : 198
# 바로 : 182
# 느낌 : 167
# 구입 : 166
# 리뷰 : 165
# 제대로 : 162
# 판매 : 161
# 효과 : 159
# 이건 : 158
# 연락 : 156
# 환불 : 153
# 절대 : 151
# 기분 : 151
# 전혀 : 150
# 여기 : 146
# 조금 : 139
# 마감 : 138
# 계속 : 137
# 시간 : 130
# 이번 : 129
# 구멍 : 118
# 사지 : 116
# 색상 : 116
# 조립 : 116
# 처리 : 115
# 전화 : 114
# 아주 : 113
# 일주일 : 112
# 고정 : 111
# 고장 : 111
